# %% [markdown]
# # NLP: buscando entidades em documentos

# %% [markdown]
# ## 01. Identificando entidades básicas

# %% [markdown]
# ### Leitura dos textos

# %%
import zipfile

# %%
with zipfile.ZipFile('./texts.zip', 'r') as zip:
    print(zip.namelist())
# Out:
# ['ADI2TJDFT.txt', 'adi3767.txt', 'Ag10000170733596001.txt', 'Ag10105170208398001.txt', 'AgAIRR11889820145030011.txt', 'AgCr10582160008758001.txt', 'AgRgSTJ1.txt', 'AgRgSTJ2.txt', 'AgRgTSE1.txt', 'AgRgTSE3.txt', 'AIAgRAgI6193ARAGUARIMG.txt', 'airr801422012.txt', 'AIRR3999520145020086.txt', 'AIRR15708820115050222.txt', 'AP00000794920137060006.txt', 'AP00001415620157010201.txt', 'AP00001441420167030203.txt', 'AP771420167080008PA.txt', 'CP32320177080008PA.txt', 'DespSEPLAGDF.txt', 'ED1STM.txt', 'ED1TJAC.txt', 'EDAgRgTSE2.txt', 'EDEDARR208420135040232.txt', 'EDRR1TST.txt', 'EEDRR9715120105020002.txt', 'ERR731004520105130003.txt', 'HC110260SP.txt', 'HC151914AgRES.txt', 'HC340624SP.txt', 'HC418951PR.txt', 'HC70000845920187000000.txt', 'lei11340.txt', 'Lei11788.txt', 'LoaDF2018.txt', 'Pet128TSE5.txt', 'Port77DF.txt', 'Rcl3495STJ.txt', 'REE5908TSE4.txt', 'REsp1583083RS.txt', 'RR474820145230056.txt', 'RR942006420095040028.txt', 'RR2574407120025020372.txt', 'TCU4687.txt', 'TSTRR16037920105200001.txt', 'AC1TCU.txt', 'AC1TJAC.txt', 'AC1TJMG.txt', 'AC2.txt', 'ACORDAOTCU25052016.txt']

# %%
with zipfile.ZipFile('./texts.zip', 'r') as zip:
    print(*zip.namelist(), sep='\n')
# Out:
# ADI2TJDFT.txt
# adi3767.txt
# Ag10000170733596001.txt
# Ag10105170208398001.txt
# AgAIRR11889820145030011.txt
# AgCr10582160008758001.txt
# AgRgSTJ1.txt
# AgRgSTJ2.txt
# AgRgTSE1.txt
# AgRgTSE3.txt
# AIAgRAgI6193ARAGUARIMG.txt
# airr801422012.txt
# AIRR3999520145020086.txt
# AIRR15708820115050222.txt
# AP00000794920137060006.txt
# AP00001415620157010201.txt
# AP00001441420167030203.txt
# AP771420167080008PA.txt
# CP32320177080008PA.txt
# DespSEPLAGDF.txt
# ED1STM.txt
# ED1TJAC.txt
# EDAgRgTSE2.txt
# EDEDARR208420135040232.txt
# EDRR1TST.txt
# EEDRR9715120105020002.txt
# ERR731004520105130003.txt
# HC110260SP.txt
# HC151914AgRES.txt
# HC340624SP.txt
# HC418951PR.txt
# HC70000845920187000000.txt
# lei11340.txt
# Lei11788.txt
# LoaDF2018.txt
# Pet128TSE5.txt
# Port77DF.txt
# Rcl3495STJ.txt
# REE5908TSE4.txt
# REsp1583083RS.txt
# RR474820145230056.txt
# RR942006420095040028.txt
# RR2574407120025020372.txt
# TCU4687.txt
# TSTRR16037920105200001.txt
# AC1TCU.txt
# AC1TJAC.txt
# AC1TJMG.txt
# AC2.txt
# ACORDAOTCU25052016.txt

# %%
with zipfile.ZipFile('./texts.zip', 'r') as zip:
    with zip.open('ADI2TJDFT.txt') as arquivo:
        texto = arquivo.read().decode('utf-8')

# %%
texto[:300]
# Out:
# 'Órgão\t:\tConselho Especial\nClasse\t:\tADI  Ação Direta de Inconstitucionalidade\nN. Processo\t:\t2010002019357-4\nRequerente(s)\t:\tPROCURADORA-GERAL DE JUSTIÇA DO DISTRITO FEDERAL E TERRITÓRIOS\nRequerido(s)\t:\tPRESIDENTE DA CÂMARA LEGISLATIVA DO DISTRITO FEDERAL E OUTRO(S)\nRelator \t:\tDesembargador LÉCIO RESE'

# %% [markdown]
# ### Parar saber mais: o que é reconhecimento de entidades nomeadas
#
# O Reconhecimento de Entidades Nomeadas (NER, do inglês **Named Entity Recognition**) é uma técnica de processamento de linguagem natural que identifica e classifica automaticamente informações específicas dentro de um texto. Essas informações são chamadas de "entidades" e geralmente correspondem a nomes de pessoas, locais, organizações, datas, quantidades ou alguma outra classificação.
#
# Por exemplo, em uma frase como "João nasceu em 10/09/1900 em Florianópolis", o NER pode identificar "João" como uma pessoa, "10/09/1900" como uma data e "Florianópolis" como um local.
#
# #### Como funciona o NER?
#
# O NER trabalha em duas etapas principais:
#
# 1. **Detecção de Entidades**: a primeira etapa é encontrar palavras ou grupos de palavras que representam possíveis entidades. Isso envolve dividir o texto em partes menores, coo frases ou palavras, um processo chamado de **tokenização**.
# 2. **Classificação das Entidades**: após identificar os possíveis candidatos, o NER classifica cada entidade em categorias predefinidas, como pessoa, local, organização, etc. Isso pode ser feito usando técnicas de aprendizado de máquina, que treinam modelos em grandes conjuntos de dados rotulados, ou usando regras manuais pré-definidas.
#
# #### Principais Aplicações do NER
#
# 1. **Motores de Busca**
#
# Motores de busca, como Google e Bing, utilizam NER para entender as intenções de busca dos usuários. Quando alguém pesquisa por "hotéis em Nova York", o NER identifica "hotéis" como um tipo de serviço e "Nova York" como uma localização, ajudando o motor de busca a apresentar resultados mais relevantes.
#
# 2. **Análise de Sentimento e Monitoramento de Mídias Sociais**
#
# Empresas usam NER para monitorar menções de suas marcas em redes sociais e na web. Por exemplo, se uma companhia quer saber quantas vezes foi mencionada e qual o contexto dessas menções, o NER pode identificar o nome da empresa e analisar os comentários relacionados para detectar sentimentos positivos ou negativos.
#
# 3. **Sistemas de Atendimento ao Cliente**
#
# Em chats e assistentes virtuais, o NER pode ajudar a identificar informações relevantes fornecidas pelo usuário, como nomes de produtos, datas e locais, para melhorar a precisão das respostas. Isso faz com que os sistemas de atendimento sejam mais eficientes e personalizados.
#
# 4. **Extração de Informações Médicas**
#
# No setor de saúde, o NER pode ser usado para extrair informações importantes de prontuários médicos, como nomes de medicamentos, sintomas, diagnósticos e datas. Isso ajuda os profissionais de saúde a analisar grandes volumes de dados de forma mais rápida e precisa.
#
# 5. **Análise de Documentos Legais**
#
# Advogados utilizam NER para identificar automaticamente cláusulas, datas e nomes de partes em contratos e documentos legais. Isso reduz o tempo necessário para revisar documentos e aumenta a precisão das análises.
#
# O Reconhecimento de Entidades Nomeadas é uma ferramenta poderosa, com aplicações em diversas áreas. Ao identificar e classificar automaticamente informações específicas em textos, o NER facilita a análise de dados e torna o processamento de grandes volumes de informação mais eficiente.

# %% [markdown]
# ### Reconhecendo as entidades no texto

# %%
# !.venv/bin/python -m spacy download pt_core_news_sm

# %%
import spacy
import pt_core_news_sm

modelo_ner = pt_core_news_sm.load()

# %%
doc = modelo_ner(texto)

for entidade in doc.ents:
    print(f"{entidade.text} → {entidade.label_}")
# Out:
# Órgão → LOC
# Conselho Especial
# Classe → ORG
# ADI → ORG
# Ação Direta de Inconstitucionalidade
# N. Processo → ORG
# Requerente(s → LOC
# JUSTIÇA → PER
# DISTRITO FEDERAL → LOC
# TERRITÓRIOS
# Requerido(s → LOC
# DISTRITO FEDERAL → LOC
# OUTRO(S → MISC
# Relator → LOC
# LEIS DISTRITAIS → MISC
# COMPLEMENTAR DISTRITAL → PER
# INCONSTITUCIONALIDADE FORMAL → MISC
# ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# ÁREA PÚBLICA → PER
# GOVERNADOR → ORG
# DISTRITO FEDERAL → LOC
# VÍCIO FORMAL → ORG
# Decreto → PER
# Portaria → MISC
# Instituto Brasileiro do Patrimônio Cultural  IBPC → LOC
# Instituto do Patrimônio Histórico e Artístico Nacional  IPHAN → LOC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# ACÓRDÃO
#  → LOC
# Acordam os Desembargadores do Conselho Especial do Tribunal de Justiça do Distrito Federal → MISC
# Territórios LÉCIO → ORG
# RESENDE  Relator → LOC
# JOÃO MAIORISI   → MISC
# Vogal → ORG
# Vogal → LOC
# DÁCIO VIEIRA  Vogal → LOC
# SÉRGIO BITTENCOURT → ORG
# Vogal → ORG
# LECIR → ORG
# Vogal → ORG
# CARMELITA BRASIL → ORG
# Vogal → ORG
# Vogal → ORG
# J.J. COSTA CARVALHO  Vogal → LOC
# HUMBERTO → LOC
# Vogal → ORG
# NÍDIA → LOC
# Vogal → ORG
# CRUZ MACEDO → ORG
# Vogal → LOC
# ROBERBAL CASEMIRO → MISC
# Vogal → LOC
# SILVÂNIO BARBOSA → LOC
# SANTOS   → ORG
# Vogal → ORG
# OTÁVIO AUGUSTO → ORG
# Vogal → ORG
# Desembargador OTÁVIO AUGUSTO → MISC
# JULGOU-SE PROCEDENTE → MISC
# Brasília → LOC
# DF → LOC
# Des → MISC
# RESENDE
#  → LOC
# DISTRITO FEDERAL → LOC
# Ação Direta de Inconstitucionalidade → MISC
# Leis → MISC
# Lei Complementar → MISC
# Região Administrativa do Paranoá  RA VII → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal  LODF → MISC
# Narra → LOC
# Chefe do Poder Executivo → MISC
# Poder Legislativo → MISC
# Leis → MISC
# Lei Complementar → MISC
# fls → PER
# Presidente da Câmara Legislativa do Distrito Federal → ORG
# fls → PER
# Governador do Distrito Federal → LOC
# Sustenta → PER
# Câmara → LOC
# LODF → LOC
# Governador do Distrito Federal → LOC
# fls → MISC
# Procurador-Geral do Distrito Federal → LOC
# Parecer Ministerial de fls → PER
# Relatório → LOC
# S
#
# O Senhor Desembargador LÉCIO → MISC
# RESENDE  Relator
#  → LOC
# DISTRITO FEDERAL → LOC
# Ação Direta de Inconstitucionalidade → MISC
# Leis → MISC
# Lei Complementar → MISC
# Região Administrativa do Paranoá  RA VII → LOC
# Chefe do Poder Executivo → MISC
# Poder Legislativo → MISC
# XI → LOC
# Lei Orgânica do Distrito Federal  LODF → MISC
# Lei Orgânica do Distrito Federal → MISC
# Ação Direta → PER
# Carta Magna → LOC
# Ação Direta de Inconstitucionalidade → ORG
# Carta Magna → LOC
# Constituição Federal → LOC
# Art. 125   → MISC
# Estados → LOC
# Constituição → ORG
# § → ORG
# Estados → LOC
# Constituição → ORG
# Ficou → MISC
# Distrito Federal → LOC
# Lei Orgânica → MISC
# Distrito Federal → LOC
# Federação brasileira → ORG
# Ministro CELSO DE MELLO → MISC
# ADI → ORG
# A Lei Orgânica do Distrito Federal → MISC
# Federação brasileira → ORG
# Distrito Federal → LOC
# Lei Orgânica → MISC
# Constituições → LOC
# Estados-membros → MISC
# DJU → MISC
# Lei Orgânica do Distrito Federal → MISC
# Estados-membros → MISC
# Supremo Tribunal Federal → LOC
# ADI → ORG
# DF → LOC
# Tribunal de Justiça do Distrito Federal → ORG
# Territórios → LOC
# Lei Orgânica do Distrito Federal → MISC
# Admito → LOC
# Ação Direta de Inconstitucionalidade → ORG
# Ação Declaratória de Constitucionalidade → ORG
# Tribunal de Justiça do Distrito Federal → ORG
# Territórios → LOC
# Carta Magna → ORG
# Regimento Interno → MISC
# Tribunal de Justiça → ORG
# Procurador-Geral de Justiça do Distrito Federal → ORG
# Territórios → LOC
# Ação Direta de Inconstitucionalidade → MISC
# Admito → LOC
# Excelentíssima Senhora PROCURADORA-GERAL DE JUSTIÇA → MISC
# DISTRITO FEDERAL → LOC
# TERRITÓRIOS → MISC
# Leis → MISC
# Autor do Projeto → MISC
# Promulgação → MISC
# Distrito Federal → LOC
# Projeto de Lei que Autoriza → MISC
# Poder Executivo → MISC
# Zona de Expansão Urbana do Paranoá → LOC
# Faço → LOC
# Câmara Legislativa do Distrito Federal → LOC
# Lei Orgânica do Distrito Federal → MISC
# Lei nº 747 → MISC
# Art. 1º Fica o Poder Executivo → MISC
# Zona de Expansão Urbana 1 → LOC
# Paranoá → ORG
# Lei nº 353 → MISC
# Vila Paranoá → LOC
# Programa de Assentamento da População de Baixa Renda → MISC
# Art. 2º → MISC
# Poder Executivo → MISC
# Decreto → LOC
# Associação de Moradores do Paranoá → ORG
# Art. 3º → MISC
# Zona de Expansão Urbana 1 → LOC
# Paranoá → ORG
# Área de Proteção Ambiental → LOC
# Lago Paranoá → LOC
# Poder Executivo → MISC
# Lei → MISC
# Art. 5º → MISC
# Art. 6º Revogam-se → MISC
# Nº → MISC
# Autoria do Projeto → MISC
# Deputado José Edmar → PER
# Destina → LOC
# Complexo Vivencial e Esportivo do Paranoá → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# Faço → LOC
# Câmara Legislativa do Distrito Federal → LOC
# Governador do Distrito Federal → LOC
# § → ORG
# Lei Orgânica do Distrito Federal → MISC
# Presidente da Câmara Legislativa do Distrito Federal → MISC
# Lei:
# Art. 1º → MISC
# Complexo Vivencial e Esportivo do Paranoá → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# I  as Quadras 3 → MISC
# II → LOC
# DF → LOC
# III → LOC
# DF → LOC
# IV → MISC
# Região Administrativa do Paranoá → LOC
# Complexo Vivencial e Esportivo do Paranoá → LOC
# III → MISC
# IV → MISC
# Art. 3º → MISC
# Plano Diretor Local do Paranoá → MISC
# Plano Diretor de Ordenamento Territorial do Distrito Federal  PDOT → MISC
# Art. 4º → MISC
# Art. 5º Revogam-se → MISC
# LEI COMPLEMENTAR → MISC
# Autoria do Projeto → MISC
# Dispõe → PER
# Região Administrativa do Paranoá  RA VII → LOC
# Presidente da Câmara Legislativa do Distrito Federal → MISC
# § → ORG
# Lei Orgânica do Distrito Federal → MISC
# Lei Complementar → PER
# Projeto → MISC
# Governador do Distrito Federal → LOC
# Câmara Legislativa do Distrito Federal → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# I → MISC
# DF-001 → LOC
# Estrada Parque Contorno  EPCT → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# Rodovia DF-001 → LOC
# EPCT → LOC
# Anexo II da Lei Complementar → MISC
# Art. 2º Fica → MISC
# Art. 3º → MISC
# Uso → LOC
# Gabarito → LOC
# Lei Complementar → PER
# Região Administrativa do Paranoá  RA VII → LOC
# Lei Complementar → PER
# Art. 5º → MISC
# Art. 6º Revogam-se → MISC
# Lei Orgânica do Distrito Federal → MISC
# Art. 3º → MISC
# Distrito Federal → LOC
# XI → LOC
# Brasília → LOC
# Livro do Tombo Histórico → MISC
# Decreto → LOC
# Portaria → MISC
# Instituto Brasileiro do Patrimônio Cultural - IBPC → LOC
# Instituto do Patrimônio Histórico e Artístico Nacional → LOC
# Inciso → PER
# Emenda a Lei Orgânica → MISC
#  DODF → MISC
# Art. 52 → MISC
# Poder Executivo → MISC
# Distrito Federal → LOC
# Câmara Legislativa → LOC
# Art. 100 → MISC
# Governador do Distrito Federal → LOC
# Lei Orgânica → MISC
# Executivo atribuições administrativas que → MISC
# Art. 321 → MISC
# Poder Executivo → MISC
# Distrito Federal → LOC
# Deputados Distritais → PER
# fls → ORG
# Poder Legislativo → LOC
# Distrito Federal → LOC
# Chefe do Poder Executivo → MISC
# Corte → LOC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE → MISC
# Nº → MISC
# PROJETO DE AUTORIA PARLAMENTAR → MISC
# COLIDÊNCIA → ORG
# A LEI ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# RESERVA DE INICIATIVA → PER
# VÍCIO FORMAL DE INCONSTITUCIONALIDADE → ORG
# GOVERNADOR → ORG
# DISTRITO FEDERAL → LOC
# PROPOSITURA → ORG
# NO ÂMBITO → MISC
# DISTRITO FEDERAL → LOC
# Tribunal de Justiça → ORG
# Poder Legislativo → MISC
# Distrito Federal → LOC
# seara → LOC
# Governador do Distrito Federal → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Lei Complementar → MISC
# Câmara Legislativa do Distrito Federal → LOC
# Lei Complementar Distrital → MISC
# ADI 2010002007992-9 → MISC
# Conselho Especial, → ORG
# Relator Desembargador NATANAEL CAETANO → MISC
# DJ-e → MISC
# COMPLEMENTARES → MISC
# USO → MISC
# OCUPAÇÃO OU DESAFETAÇÃO DE ÁREAS PÚBLICAS → MISC
# DEPUTADOS DISTRITAIS → PER
# INCONSTITUCIONALIDADE FORMAL → MISC
# MODULAÇÃO → ORG
# INAPLICABILIDADE → LOC
# Distrito Federal → LOC
# Governador → LOC
# Lei Orgânica do Distrito Federal → MISC
# Lei → MISC
# ADI 2010002002050-8 → MISC
# Conselho Especial, → ORG
# Relator Desembargador SÉRGIO BITTENCOURT → MISC
# DJ-e → MISC
# CONSTITUCIONAL → LOC
# ADMINISTRATIVO → MISC
# DESAFETAÇÃO → ORG
# QUADRAS RESIDENCIAIS DE BRAZLÂNDIA-DF → MISC
# RA IV → MISC
# FORMAL → MISC
# EMENDA PARLAMENTAR → MISC
# LEI ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# Lei Complementar → MISC
# Brazlândia-DF → LOC
# Região Administrativa IV → LOC
# Distrito Federal → LOC
# Chefe do Poder Executivo local → MISC
# Corte → LOC
# ADI 2009002013564-6 → MISC
# Conselho Especial, Relator Desembargador CRUZ MACEDO → ORG
# DJ-e → MISC
# Distrito Federal → LOC
# Decreto → LOC
# Portaria n.º 314/1992 → MISC
# Instituto Brasileiro do Patrimônio Histórico e Artístico Nacional  IPHAN → LOC
# Governador → LOC
# Distrito Federal → LOC
# Câmara Legislativa → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Distrito Federal → LOC
# XI → LOC
# Brasília → LOC
# Livro do Tombo Histórico → MISC
# Decreto → LOC
# Portaria n 314 → MISC
# Instituto Brasileiro do Patrimônio Cultural  IBPC → LOC
# Instituto do patrimônio Histórico e Artístico Nacional  IPHAN → LOC
# Decreto → PER
# Portaria n.º 314/1992 → MISC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Art. 14   → MISC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Decreto → PER
# Lei Orgânica do Distrito Federal → MISC
# Emenda → LOC
# LODF → ORG
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Decreto → PER
# Portaria → ORG
# IPHAN → MISC
# LODF → ORG
# Distrito Federal → LOC
# JULGO PROCEDENTE → PER
# Leis → MISC
# Lei Complementar → MISC
# O Senhor Desembargador JOÃO MARIOSI   → MISC
# Vogal
# Senhor Presidente → LOC
# Constituição de 1988 → MISC
# Distrito Federal → LOC
# Ministro Celso de Mello → LOC
# S. → LOC
# Tribunal → LOC
# Judiciário → MISC
# Constituição → ORG
# Constituição → ORG
# “ → PER
# Tribunal → LOC
# Câmara Legislativa → LOC
# Governador do Distrito Federal → LOC
# Supremo → LOC
# Tribunal → ORG
# Evidentemente → MISC
# Lei Orgânica do Distrito Federal → MISC
# Constituições Estaduais → LOC
# Constituições Estaduais → LOC
# Estados → LOC
# Federação → LOC
# Distrito Federal → LOC
# Poder Judiciário → MISC
# Ministério Público → LOC
# Ministério Público → LOC
# Distrito Federal → LOC
# Tribunal de Contas → ORG
# Digo → LOC
# Vencido → LOC
# O Senhor Desembargador ROMÃO → MISC
# Vogal
# Senhor → LOC
# Desembargador João Mariosi → PER
# Relator → PER
# O Senhor Desembargador DÁCIO VIEIRA  Vogal → MISC
# Ação Direta de Inconstitucionalidade → PER
# Procuradora-Geral de Justiça do Distrito Federal → ORG
# Territórios → LOC
# Leis Distritais → LOC
# Lei Complementar → MISC
# Região Administrativa do Paranoá  RA VII → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Sustenta → PER
# “ → PER
# Deputados Distritais → PER
# Governador do Distrito Federal → LOC
# Lei Orgânica do Distrito Federal → MISC
# Órgão Especial → LOC
# Distrito Federal → LOC
# Governador do Distrito Federal → LOC
# ”(Conselho Especial → LOC
# ADI → ORG
# Rel → ORG
# Des → PER
# C. Oliveira → PER
# Reg → PER
# Ac → MISC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE → MISC
# COMPLEMENTARES → MISC
# Nº 660 → MISC
# ALTERAÇÃO → PER
# CEILÂNDIA → ORG
# USO → LOC
# E OCUPAÇÃO → ORG
# SOLO → LOC
# ALEGAÇÃO DE INCONSTITUCIONALIDADE FORMAL FRENTE → MISC
# LEI ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# PROCEDÊNCIA → ORG
# Procedência → PER
# Leis Complementares → PER
# Lei Orgânica do Distrito Federal → MISC
# Decreto → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Chefe do Poder Executivo → MISC
# Leis Complementares → MISC
# 29/11/20 → LOC
# Relator MARIO MACHADO → MISC
# Conselho Especial → ORG
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE → MISC
# Nº → MISC
# FORMAL → MISC
# GOVERNADOR → ORG
# DISTRITO FEDERAL → LOC
# OCUPAÇÃO E USO DO → MISC
# SOLO → MISC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Conselho Especial → ORG
# ADI → ORG
# Rel → LOC
# Des → PER
# Lécio Resende → PER
# Reg → PER
# Ac → MISC
# INICIAL REJEITADA → ORG
# MÉRITO → MISC
# SOBRE OCUPAÇÃO E USO DO → ORG
# SOLO → MISC
# VÍCIO FORMAL CONFIGURADO → MISC
# GOVERNADOR → ORG
# DISTRITO FEDERAL → LOC
# Relator DÁCIO VIEIRA → PER
# Conselho Especial → ORG
# Destarte → LOC
# Leis → LOC
# Governador → LOC
# Feitas → PER
# Leis → MISC
# O Senhor Desembargador SÉRGIO BITTENCOURT → MISC
# Vogal
# Senhor Presidente → LOC
# Desembargador João Mariosi → PER
# Conselho → ORG
# Admito → LOC
# Ação Direta de Inconstitucionalidade → MISC
# Governador do Distrito Federal → LOC
# Leis Distritais → LOC
# Lei Complementar Distrital → MISC
# Deputados Distritais → PER
# Aduz → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Leis Distritais → PER
# Presidente da Câmara Legislativa → ORG
# fls → PER
# Governador do Distrito Federal → LOC
# Procurador-Geral do Distrito Federal → LOC
# fls → MISC
# Procuradoria de Justiça → MISC
# fls → PER
# Leis → MISC
# Deputados Distritais → PER
# Governador do Distrito Federal → LOC
# Presidente da Câmara Legislativa → MISC
# Diplomas → MISC
# Leis Distritais → PER
# Autoria do Projeto → MISC
# Promulgação → MISC
# Distrito Federal → LOC
# Projeto de Lei que Autoriza → MISC
# Poder Executivo → MISC
# Zona de Expansão Urbana do Paranoá → LOC
# Faço → LOC
# Câmara Legislativa do Distrito Federal → LOC
# Lei Orgânica do Distrito Federal → MISC
# Lei nº 747 → MISC
# Art. 1º Fica o Poder Executivo → MISC
# Zona de Expansão Urbana 1 → LOC
# Paranoá → ORG
# Lei nº 353 → MISC
# Vila Paranoá → LOC
# Programa de Assentamento da População de Baixa Renda → MISC
# Art. 2º → MISC
# Poder Executivo → MISC
# Decreto → LOC
# Associação de Moradores do Paranoá → ORG
# Art. 3º → MISC
# Zona de Expansão Urbana 1 → LOC
# Paranoá → ORG
# Área de Proteção Ambiental → LOC
# Lago Paranoá → LOC
# Poder Executivo → MISC
# Lei → MISC
# Art. 5º → MISC
# Art. 6º Revogam-se → MISC
# Nº → MISC
# Autoria do Projeto → MISC
# Deputado José Edmar → PER
# Destina → LOC
# Complexo Vivencial e Esportivo do Paranoá → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# Faço → LOC
# Câmara Legislativa do Distrito Federal → LOC
# Governador do Distrito Federal → LOC
# § → ORG
# Lei Orgânica do Distrito Federal → MISC
# Presidente da Câmara Legislativa do Distrito Federal → MISC
# Lei:
# Art. 1º → MISC
# Complexo Vivencial e Esportivo do Paranoá → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# I  as Quadras 3 → MISC
# II → LOC
# DF → LOC
# III → LOC
# DF → LOC
# IV → MISC
# Região Administrativa do Paranoá → LOC
# Complexo Vivencial e Esportivo do Paranoá → LOC
# III → MISC
# IV → MISC
# Art. 3º → MISC
# Plano Diretor Local do Paranoá → MISC
# Plano Diretor de Ordenamento Territorial do Distrito Federal  PDOT → MISC
# Art. 4º → MISC
# Art. 5º Revogam-se → MISC
# LEI COMPLEMENTAR → MISC
# Autoria do Projeto → MISC
# Dispõe → PER
# Região Administrativa do Paranoá  RA VII → LOC
# Presidente da Câmara Legislativa do Distrito Federal → MISC
# § → ORG
# Lei Orgânica do Distrito Federal → MISC
# Lei Complementar → PER
# Projeto → MISC
# Governador do Distrito Federal → LOC
# Câmara Legislativa do Distrito Federal → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# I → MISC
# DF-001 → LOC
# Estrada Parque Contorno  EPCT → LOC
# Região Administrativa do Paranoá  RA VII → LOC
# Rodovia DF-001 → LOC
# EPCT → LOC
# Anexo II da Lei Complementar → MISC
# Art. 2º Fica → MISC
# Art. 3º → MISC
# Uso → LOC
# Gabarito → LOC
# Lei Complementar → PER
# Região Administrativa do Paranoá  RA VII → LOC
# Lei Complementar → PER
# Art. 5º → MISC
# Art. 6º Revogam-se → MISC
# Governador do Distrito Federal → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Art. 3º → MISC
# Distrito Federal → LOC
# Omissis → ORG
# XI → LOC
# Brasília → LOC
# Livro do Tombo Histórico → MISC
# Decreto → LOC
# Portaria → MISC
# Instituto Brasileiro do Patrimônio Cultural  IBPC → LOC
# Instituto do Patrimônio Histórico e Artístico Nacional  IPHAN → LOC
# Poder Executivo → MISC
# Distrito Federal → LOC
# Câmara Legislativa → LOC
# Art. 100 → MISC
# Governador do Distrito Federal → LOC
# Omissis → ORG
# Lei Orgânica → MISC
# Executivo atribuições administrativas que → MISC
# Poder Executivo → MISC
# Distrito Federal → LOC
# Decreto → LOC
# Portaria nº 314/1992 → MISC
# Instituto Brasileiro do Patrimônio Histórico e Artístico Nacional → LOC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Art. 14   → MISC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Normas → LOC
# Câmara Legislativa → LOC
# Governador do Distrito Federal → LOC
# Esta Eg → MISC
# Corte → LOC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE → MISC
# LEIS → MISC
# JUNHO → MISC
# Nº → MISC
# Nº → MISC
# E Nº 2.540 → MISC
# NORMATIVOS LOCAIS → ORG
# TRIBUNAL DE JUSTIÇA → ORG
# AÇÃO → ORG
# OCUPAÇÃO → ORG
# E USO DO SOLO → MISC
# PARLAMENTARES  INCONSTITUCIONALIDADE  COMPETÊNCIA → MISC
# PODER EXECUTIVO → MISC
# Conselho Especial do Tribunal de Justiça do Distrito Federal → ORG
# Territórios → LOC
# Distrito Federal → LOC
# Lei Orgânica → MISC
# Distrito Federal → LOC
# Governador do Distrito Federal → LOC
# Rel → ORG
# Des → PER
# João Mariosi → PER
# Conselho Especial → ORG
# DJ-e → MISC
# CONSTITUCIONAL → LOC
# ALTERA → ORG
# USO DE LOTES → MISC
# QUADRA → ORG
# SETOR DE INDÚSTRIAS → ORG
# GRÁFICAS → LOC
# REGIÃO ADMINISTRATIVA DO → LOC
# PLANO PILOTO → MISC
# VÍCIO FORMAL → MISC
# GOVERNADOR → ORG
# ORGÂNICA → MISC
# FEDEAL → MISC
# Lei Orgânica do Distrito Federal → MISC
# XI → LOC
# Decreto n. 10.829/87 → MISC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Lei Orgânica → MISC
# Governador do Distrito Federal → LOC
# Lei Orgânica → MISC
# Decreto → PER
# Governador → LOC
# Distrito Federal → LOC
# Inexiste → LOC
# Lei Orgânica do Distrito Federal → MISC
# Distrito Federal → LOC
# LODF
# Julgado → LOC
# ADI → ORG
# Rel → ORG
# Des → PER
# J. J. Costa Carvalho → PER
# Conselho Especial → ORG
# DJ-e → MISC
# DISTRITAL → ORG
# DESAFETAÇÃO → ORG
# VÍCIO DE INICIATIVA → MISC
# INCONSTITUCIONALIDADE FORMAL → MISC
# PROCEDÊNCIA → ORG
# EFEITOS → MISC
# TUNC → ORG
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Lei n.º 464/1994 → MISC
# Região Administrativa do Cruzeiro → LOC
# Relª. Desa → PER
# Brasil → LOC
# Conselho Especial → ORG
# DJ-e → LOC
# Leis Distritais → LOC
# Lei Complementar Distrital → MISC
# O Senhor Desembargador LECIR MANOEL DA LUZ → MISC
# Vogal → LOC
# Desembargador Romão → PER
# C. Oliveira → PER
# Desembargador → PER
# Relator → PER
# A Senhora Desembargadora CARMELITA BRASIL → MISC
# Relator → PER
# O Senhor Desembargador WALDIR LEÔNCIO → MISC
# Relator → PER
# O Senhor Desembargador J. J. COSTA CARVALHO  Vogal
# Senhor Presidente → MISC
# Relator → PER
# Desembargador João Mariosi → PER
# O Senhor Desembargador HUMBERTO → MISC
# Relator → PER
# A Senhora Desembargadora NÍDIA CORRÊA → MISC
# Desembargador João Mariosi → PER
# Relator → PER
# O Senhor Desembargador CRUZ MACEDO → MISC
# Relator → PER
# vênia → LOC
# A Senhora Desembargadora ANA MARIA DUARTE AMARANTE   → MISC
# Relator → PER
# O Senhor Desembargador ROBERVAL → MISC
# Vogal
#  → LOC
# Relator → PER
# vênia → LOC
# O Senhor Desembargador SILVÂNIO BARBOSA → MISC
# SANTOS   → ORG
# Relator → PER
# vênia → LOC
# O Senhor Desembargador OTÁVIO AUGUSTO  Presidente → MISC
# Vogal
#  → LOC
# Procuradora-Geral de Justiça do Distrito Federal → ORG
# Territórios → LOC
# Leis Distritais → LOC
# Lei Complementar → MISC
# XI → LOC
# Lei Orgânica do DF → MISC
# Lei Orgânica do DF → MISC
# XI → LOC
# Chefe do Poder Executivo → MISC
# DF → LOC
# Requer → MISC
# Deputados Distritais → PER
# Poder Legislativo → LOC
# Distrito Federal → LOC
# Governador do Distrito Federal → LOC
# Lei Orgânica do Distrito Federal → MISC
# Poder Executivo → MISC
# Distrito Federal → LOC
# Câmara Legislativa → LOC
# Art. 100 → MISC
# Governador do Distrito Federal → LOC
# Lei Orgânica → MISC
# Poder Executivo → MISC
# Distrito Federal → LOC
# DF → LOC
# Distrito Federal → LOC
# Poder Executivo → MISC
# Decreto → LOC
# XI → LOC
# LODF → ORG
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# Lei Orgânica → MISC
# Governador do Distrito Federal → LOC
# Lei Orgânica → MISC
# Decreto → PER
# Governador do Distrito Federal → LOC
# Conselho → ORG
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE → MISC
# COMPLEMENTARES → MISC
# Nº 660 → MISC
# ALTERAÇÃO → PER
# CEILÂNDIA → ORG
# USO → LOC
# E OCUPAÇÃO → ORG
# SOLO → LOC
# ALEGAÇÃO DE INCONSTITUCIONALIDADE FORMAL FRENTE → MISC
# LEI ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# PROCEDÊNCIA → ORG
# Procedência → PER
# Leis Complementares → PER
# Lei Orgânica do Distrito Federal → MISC
# Decreto → LOC
# XI → LOC
# Lei Orgânica do Distrito Federal → MISC
# Chefe do Poder Executivo → MISC
# Leis Complementares → MISC
# 29/11/20 → LOC
# Relator MARIO MACHADO → MISC
# Conselho Especial → ORG
# INICIATIVA PARLAMENTAR → LOC
# CATETINHO - VIOLAÇÃO → MISC
# LEI ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# VÍCIO FORMAL → MISC
# PROCEDÊNCIA → ORG
# PEDIDO → ORG
# Distrito Federal → LOC
# Lei Orgânica do Distrito Federal → MISC
# Chefe do Poder Executivo → MISC
# Distrito Federal → LOC
# Procedência → PER
# Lei Distrital → MISC
# Setor → LOC
# Habitacional Catetinho → PER
# Relator HUMBERTO → PER
# Conselho Especial → ORG
# DISPÕE SOBRE PARÂMETROS DE OCUPAÇÃO DE ÁREAS → MISC
# DISTRITO FEDERAL → LOC
# VÍCIO DE INICIATIVA → MISC
# GOVERNADOR → ORG
# DISTRITO FEDERAL → LOC
# INCONSTITUCIONALIDADE FORMAL → MISC
# OFENSA → ORG
# ARTS → ORG
# INCISO VI → PER
# LEI ORGÂNICA → MISC
# DISTRITO FEDERAL → LOC
# Lei de autoria → MISC
# Distrito Federal → LOC
# Chefe do Poder Executivo → MISC
# Ação → MISC
# Maioria → LOC
# Relator OTÁVIO AUGUSTO → PER
# Conselho Especial → ORG
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE → MISC
# COMPLEMENTARES → MISC
# FORMAL → MISC
# MATERIAL → ORG
# OCORRÊNCIA → ORG
# PROCEDÊNCIA → ORG
# PEDIDO PARA DECLARAR → MISC
# A INCONSTITUCIONALIDADE DAS LEIS → MISC
# EFEITOS → MISC
# TUNCE → MISC
# ERGA OMNES → ORG
# LODF → LOC
# Governador do Distrito Federal → LOC
# Distrito Federal → LOC
# LODF → ORG
# LODF → LOC
# Ação Direta de Inconstitucionalidade → ORG
# ADI → ORG
# Relator Des → PER
# Hermenegildo Gonçalves → PER
# DJU → MISC
# Manifesto → MISC
# Distrito Federal → LOC
# Noutro passo → LOC
# Presidente da Câmara Legislativa → MISC
# fls → ORG
# LODF → ORG
# Câmara Legislativa → LOC
# LODF → LOC
# Câmara Legislativa → LOC
# Distrito Federal → LOC
# Chefe do Poder Executivo → MISC
# Distrito Federal → LOC
# Decreto → LOC
# Portaria → MISC
# Instituto Brasileiro do Patrimônio Histórico e Artístico Nacional  IPHAN → LOC
# Senhor Governador do Distrito Federal → LOC
# Poder Legislativo Distrital → MISC
# Destarte → LOC
# Deputados Distritais → PER
# Poder Executivo → MISC
# PROCEDENTE → LOC
# Leis Distritais → LOC
# Lei Complementar → MISC
# D E C I S Ã O
# Julgou-se → MISC

# %%
import pandas as pd

# %%
entidades = []
labels = []

for entidade in doc.ents:
    entidades.append(entidade.text)
    labels.append(entidade.label_)

# %%
pd.DataFrame({'Entidade': entidades, 'Label': labels})
# Out:
#                                               Entidade Label
# 0                                                Órgão   LOC
# 1                            Conselho Especial\nClasse   ORG
# 2                                                  ADI   ORG
# 3    Ação Direta de Inconstitucionalidade\nN. Processo   ORG
# 4                                         Requerente(s   LOC
# ..                                                 ...   ...
# 867                                    Poder Executivo  MISC
# 868                                         PROCEDENTE   LOC
# 869                                    Leis Distritais   LOC
# 870                                   Lei Complementar  MISC
# 871                           D E C I S Ã O\nJulgou-se  MISC
#
# [872 rows x 2 columns]

# %% [markdown]
# ### Visualizando as entidades no texto

# %%
modelo_ner.get_pipe('ner').labels
# Out:
# ('LOC', 'MISC', 'ORG', 'PER')

# %%
print('LOC', spacy.explain('LOC'))
print('MISC', spacy.explain('MISC'))
print('ORG', spacy.explain('ORG'))
print('PER', spacy.explain('PER'))
# Out:
# LOC Non-GPE locations, mountain ranges, bodies of water
# MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# ORG Companies, agencies, institutions, etc.
# PER Named person or family.

# %%
from IPython.display import display
from spacy import displacy

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Órgão
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# 	:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Conselho Especial
# Classe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 	:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ADI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ação Direta de Inconstitucionalidade
# N. Processo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 	:	2010002019357-4<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Requerente(s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )	:	PROCURADORA-GERAL DE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JUSTIÇA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  DO
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  E
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TERRITÓRIOS
# Requerido(s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )	:	PRESIDENTE DA CÂMARA LEGISLATIVA DO
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  E
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUTRO(S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# )<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Relator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  	:	Desembargador LÉCIO RESENDE<br>	EMENTA	<br>AÇÃO DIRETA DE INCONSTITUCIONALIDADE.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEIS DISTRITAIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  N.º 747/1994 E 2018/1998. LEI
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COMPLEMENTAR DISTRITAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  N.º 380/2001.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     INCONSTITUCIONALIDADE FORMAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# . LEI
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ORGÂNICA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  DO
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . OCUPAÇÃO DE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ÁREA PÚBLICA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . COMPETÊNCIA PRIVATIVA DO
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GOVERNADOR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  DO
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . AÇÃO JULGADA PROCEDENTE EM RAZÃO DO
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VÍCIO FORMAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Tanto o
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Decreto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  n.º 10.829/87, quanto a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Portaria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  n.º 314/92, do
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instituto Brasileiro do Patrimônio Cultural  IBPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , hoje
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instituto do Patrimônio Histórico e Artístico Nacional  IPHAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , conferem ao
# <mark class="entity" style="backgro

# %%
# !.venv/bin/python -m spacy download en_core_web_sm

# %%
import en_core_web_sm

modelo_ner_ing = spacy.load('en_core_web_sm')
modelo_ner_ing.get_pipe('ner').labels
# Out:
# ('CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %% [markdown]
# ## 02. Preparando os dados para treinamento

# %% [markdown]
# ### Tokenizando os dados

# %%
dados = []

with zipfile.ZipFile('./texts.zip') as zip:
    for nome_arquivo in zip.namelist():
        with zip.open(nome_arquivo) as arquivo:
            conteudo = arquivo.read().decode('utf-8')
            palavras = conteudo.split()
            for palavra in palavras:
                dados.append([nome_arquivo, palavra])

tabela_palavras = pd.DataFrame(dados, columns=['arquivo', 'palavra'])

# %%
tabela_palavras
# Out:
#                        arquivo              palavra
# 0                ADI2TJDFT.txt                Órgão
# 1                ADI2TJDFT.txt                    :
# 2                ADI2TJDFT.txt             Conselho
# 3                ADI2TJDFT.txt             Especial
# 4                ADI2TJDFT.txt               Classe
# ...                        ...                  ...
# 193487  ACORDAOTCU25052016.txt  Ministro-Substituto
# 193488  ACORDAOTCU25052016.txt              AUGUSTO
# 193489  ACORDAOTCU25052016.txt              SHERMAN
# 193490  ACORDAOTCU25052016.txt           CAVALCANTI
# 193491  ACORDAOTCU25052016.txt              Relator
#
# [193492 rows x 2 columns]

# %%
tabela_palavras.to_csv('palavras.csv', index=False, sep='\t')

# %% [markdown]
# ### Rotulando os dados no formato IOB (*Inside*, *Outside*, *Beginning*)

# %%
tabela_palavras = pd.read_csv('./palavras_IOB.tsv', sep='\t')

# %%
tabela_palavras
# Out:
#                           arquivo     palavra          label
# 0                     TCU4687.txt       GRUPO              O
# 1                     TCU4687.txt           I              O
# 2                     TCU4687.txt      CLASSE              O
# 3                     TCU4687.txt          II              O
# 4                     TCU4687.txt          2ª  B-ORGANIZACAO
# ...                           ...         ...            ...
# 229272  RR2574407120025020372.txt          de              O
# 229273  RR2574407120025020372.txt      Chaves              O
# 229274  RR2574407120025020372.txt    Públicas              O
# 229275  RR2574407120025020372.txt  Brasileira              O
# 229276  RR2574407120025020372.txt           .              O
#
# [229277 rows x 3 columns]

# %%
tabela_palavras['label'].unique()
# Out:
# array(['O', 'B-ORGANIZACAO', 'I-ORGANIZACAO', 'B-JURISPRUDENCIA',
#        'I-JURISPRUDENCIA', 'B-PESSOA', 'I-PESSOA', 'B-LEGISLACAO',
#        'I-LEGISLACAO', 'B-TEMPO', 'B-LOCAL', 'I-LOCAL', 'I-TEMPO'],
#       dtype=object)

# %% [markdown]
# ### Para saber mais: formato IOB
#
# O formato IOB (Inside-Outside-Beginning) é amplamente utilizado para rotular sequências de texto em tarefas de NLP, principalmente em tarefas de reconhecimento de entidades nomeadas (NER). Este formato ajuda a identificar palavras ou frases que pertencem a categorias específicas, como nomes de pessoas, organizações, locais e datas.
#
# Esse formato é um esquema de rotulação que classifica as palavras de uma sequência de texto em três categorias:
#
# - **B- (Beginning)**: indica o início de uma entidade. É usado para marcar a primeira palavra de uma entidade nomeada.
# - **I- (Inside)**: indica que a palavra faz parte de uma entidade, mas não é a primeira palavra. Todas as palavras subsequentes que ainda pertencem à mesma entidade são marcadas com "I".
# - **O (Outside)**: indica que a palavra não faz parte de nenhuma entidade nomeada. É utilizada para palavras que não pertencem a nenhuma categoria específica de interesse.
#
# #### Exemplo de uso
#
# Vamos usar um exemplo simples para entender como essas etiquetas são aplicadas. Considere a frase "João Miranda é instrutor na Alura".
#
# Podemos rotular as entidades "João Miranda" (Pessoa) e "Alura" (Organização) usando o formato IOB:
#
# | Palavra   | Rótulo        |
# | :-------- | :------------ |
# | João      | B-PESSOA      |
# | Miranda   | I-PESSOA      |
# | é         | O             |
# | instrutor | O             |
# | na        | O             |
# | Alura     | B-ORGANIZACAO |
#
# Neste exemplo:
# - "João" é rotulado como **B-PESSOA**, indicando o início de uma entidade do tipo "Pessoa".
# - "Miranda" é rotulado como **I-PESSOA**, pois faz parte da mesma entidade "Pessoa" que começou com "João".
# - "Alura " é rotulado como B-ORGANIZACAO, indicando o início de uma entidade do tipo "Organização".
# - As palavras "é", "instrutor", "na" são rotuladas como O, já que não pertencem a nenhuma entidade de interesse. Caso fosse interessante no projeto, a palavra instrutor poderia fazer parte de um rótulo, como por exemplo "Cargo".
#
# #### Vantagens do formato IOB
#
# 1. **Simplicidade**: é fácil de entender e aplicar. Cada palavra recebe um rótulo que indica claramente se pertence a uma entidade e, em caso positivo, se é o início ou parte de uma entidade.
# 2. **Versatilidade**: pode ser utilizado para diferentes tipos de entidades, bastando adaptar os rótulos (por exemplo, B-PESSOA, I-PESSOA, B-LOCAL, I-LOCAL, B-CARGO, I-CARGO).
# 3. **Facilidade de treinamento**: é um formato muito utilizado em modelos de aprendizado de máquina para NLP, pois fornece informações ricas e estruturadas sobre as entidades no texto.
#
# #### Limitações do formato IOB
#
# Embora seja amplamente utilizado, o formato IOB tem algumas limitações:
# - **Confusão em casos ambíguos**: em algumas situações, pode ser difícil decidir onde começa e termina uma entidade, especialmente em textos complexos.
# - **Depende de segmentação prévia**: para utilizar o formato IOB, é necessário que o texto esteja devidamente tokenizado (dividido em palavras ou subpalavras).
#
# #### Alternativas ao formato IOB
#
# Existem variações do formato IOB, como o **IOB2** e o **BIOES**:
# - **IOB2**: semelhante ao IOB, mas todos os rótulos de entidade começam com "B-" independentemente de serem a primeira palavra de uma entidade.
# - **BIOES**: adiciona dois rótulos adicionais: "E-" (End), que indica a última palavra de uma entidade, e "S-" (Single), que marca uma entidade que consiste em uma única palavra.
#
# Caso queira saber mais a respeito, acesse o artigo:
# - [Artigo Reconhecimento de Entidades Nomeadas](https://cs229.stanford.edu/proj2005/KrishnanGanapathy-NamedEntityRecognition.pdf)

# %% [markdown]
# ### Transformando dados para o formato spacy

# %% [markdown]
# Formato Spacy:
#
# ```tupla = ('texto', {'entities': [(10, 17, 'ORGANIZACAO'), (25, 40, 'PESSOA')]})```

# %%
grupo_arquivos = tabela_palavras.groupby('arquivo')

# %%
grupo_arquivos.get_group('ADI2TJDFT.txt')
# Out:
#              arquivo   palavra          label
# 46105  ADI2TJDFT.txt     Órgão              O
# 46106  ADI2TJDFT.txt         :              O
# 46107  ADI2TJDFT.txt  Conselho  B-ORGANIZACAO
# 46108  ADI2TJDFT.txt  Especial  I-ORGANIZACAO
# 46109  ADI2TJDFT.txt    Classe              O
# ...              ...       ...            ...
# 55911  ADI2TJDFT.txt         a              O
# 55912  ADI2TJDFT.txt      ação              O
# 55913  ADI2TJDFT.txt         ,              O
# 55914  ADI2TJDFT.txt   maioria              O
# 55915  ADI2TJDFT.txt         .              O
#
# [9811 rows x 3 columns]

# %%
tabela_agrupada = grupo_arquivos.get_group('ADI2TJDFT.txt')[['palavra', 'label']].values
conteudo = ''
anotacoes = {'entities': []}
inicio_palavra = 0
fim_palavra = 0

for texto, label in tabela_agrupada:
    texto = str(texto)
    tamanho_texto = len(texto) + 1

    inicio_palavra = fim_palavra
    fim_palavra = inicio_palavra + tamanho_texto

    if label != 'O':
        anotacao = (inicio_palavra, fim_palavra - 1, label)
        anotacoes['entities'].append(anotacao)

    conteudo = conteudo + texto + ' '

# %%
conteudo
# Out:
# "Órgão : Conselho Especial Classe : ADI Ação Direta de Inconstitucionalidade N . Processo : 2010002019357-4 Requerente ( s ) : PROCURADORA-GERAL DE JUSTIÇA DO DISTRITO FEDERAL E TERRITÓRIOS Requerido ( s ) : PRESIDENTE DA CÂMARA LEGISLATIVA DO DISTRITO FEDERAL E OUTRO ( S ) Relator : Desembargador LÉCIO RESENDE EMENTA AÇÃO DIRETA DE INCONSTITUCIONALIDADE . LEIS DISTRITAIS N.º 747/1994 E 2018/1998 . LEI COMPLEMENTAR DISTRITAL N.º 380/2001 . INCONSTITUCIONALIDADE FORMAL . LEI ORGÂNICA DO DISTRITO FEDERAL . OCUPAÇÃO DE ÁREA PÚBLICA . COMPETÊNCIA PRIVATIVA DO GOVERNADOR DO DISTRITO FEDERAL . AÇÃO JULGADA PROCEDENTE EM RAZÃO DO VÍCIO FORMAL . Tanto o Decreto n.º 10.829/87 , quanto a Portaria n.º 314/92 , do Instituto Brasileiro do Patrimônio Cultural IBPC , hoje Instituto do Patrimônio Histórico e Artístico Nacional IPHAN , conferem ao Governador do Distrito Federal competência privativa para iniciar o processo legislativo , quando se tratar o tema de uso e ocupação do solo em todo o território do Distrito Federal . ACÓRDÃO Acordam os Desembargadores do Conselho Especial do Tribunal de Justiça do Distrito Federal e dos Territórios LÉCIO RESENDE Relator , JOÃO MAIORISI Vogal , ROMÃO C. OLIVEIRA Vogal , DÁCIO VIEIRA Vogal , SÉRGIO BITTENCOURT Vogal , LECIR MANOEL DA LUZ Vogal , CARMELITA BRASIL Vogal , WALDIR LEÔNCIO LOPES JÚNIOR Vogal , J.J. COSTA CARVALHO Vogal , HUMBERTO ADJUTO ULHÔA Vogal , NÍDIA CORRÊA LIMA Vogal , ANA MARIA DUARTE AMARANTE BRITO Vogal , CRUZ MACEDO - Vogal , ROBERBAL CASEMIRO BELINATI Vogal , SILVÂNIO BARBOSA DOS SANTOS Vogal , OTÁVIO AUGUSTO Vogal , sob a presidência do Desembargador OTÁVIO AUGUSTO , em proferir a seguinte decisão : JULGOU-SE PROCEDENTE A AÇÃO , POR MAIORIA , de acordo com a ata do julgamento e notas taquigráficas . Brasília ( DF ) , 17 de maio de 2011 Des . LÉCIO RESENDE Relator R E L A T Ó R I O A PROCURAD
#   (499, 506, 'I-LEGISLACAO'),
#   (575, 583, 'B-LOCAL'),
#   (584, 591, 'I-LOCAL'),
#   (653, 660, 'B-LEGISLACAO'),
#   (661, 664, 'I-LEGISLACAO'),
#   (665, 674, 'I-LEGISLACAO'),
#   (686, 694, 'B-LEGISLACAO'),
#   (695, 698, 'I-LEGISLACAO'),
#   (699, 705, 'I-LEGISLACAO'),
#   (711, 720, 'B-ORGANIZACAO'),
#   (721, 731, 'I-ORGANIZACAO'),
#   (732, 734, 'I-ORGANIZACAO'),
#   (735, 745, 'I-ORGANIZACAO'),
#   (746, 754, 'I-ORGANIZACAO'),
#   (755, 759, 'B-ORGANIZACAO'),
#   (767, 776, 'B-ORGANIZACAO'),
#   (777, 779, 'I-ORGANIZACAO'),
#   (780, 790, 'I-ORGANIZACAO'),
#   (791, 800, 'I-ORGANIZACAO'),
#   (801, 802, 'I-ORGANIZACAO'),
#   (803, 812, 'I-ORGANIZACAO'),
#   (813, 821, 'I-ORGANIZACAO'),
#   (822, 827, 'B-ORGANIZACAO'),
#   (856, 864, 'B-LOCAL'),
#   (865, 872, 'I-LOCAL'),
#   (1007, 1015, 'B-LOCAL'),
#   (1016, 1023, 'I-LOCAL'),
#   (1064, 1072, 'B-ORGANIZACAO'),
#   (1073, 1081, 'I-ORGANIZACAO'),
#   (1082, 1084, 'I-ORGANIZACAO'),
#   (1085, 1093, 'I-ORGANIZACAO'),
#   (1094, 1096, 'I-ORGANIZACAO'),
#   (1097, 1104, 'I-ORGANIZACAO'),
#   (1105, 1107, 'I-ORGANIZACAO'),
#   (1108, 1116, 'I-ORGANIZACAO'),
#   (1117, 1124, 'I-ORGANIZACAO'),
#   (1143, 1148, 'B-PESSOA'),
#   (1149, 1156, 'I-PESSOA'),
#   (1167, 1171, 'B-PESSOA'),
#   (1172, 1180, 'I-PESSOA'),
#   (1189, 1194, 'B-PESSOA'),
#   (1195, 1197, 'I-PESSOA'),
#   (1198, 1206, 'I-PESSOA'),
#   (1215, 1220, 'B-PESSOA'),
#   (1221, 1227, 'I-PESSOA'),
#   (1236, 1242, 'B-PESSOA'),
#   (1243, 1254, 'I-PESSOA'),
#   (1263, 1268, 'B-PESSOA'),
#   (1269, 1275, 'I-PESSOA'),
#   (1276, 1278, 'I-PESSOA'),
#   (1279, 1282, 'I-PESSOA'),
#   (1291, 1300, 'B-PESSOA'),
#   (1301, 1307, 'I-PESSOA'),
#   (1316, 1322, 'B-PESSOA'),
#   (1323, 1330, 'I-PESSOA'),
#   (1331, 1336, 'I-PESSOA'),
#   (1337, 1343, 'I-PESSOA'),
#   (1352, 1356, 'B-PESSOA'),
#   (1357, 1362, 'I-PESSOA'),
#   (1363, 1371, 'I-PESSOA'),
#   (1380, 1388, 'B-PESSOA'),
#   (1389, 1395, 'I-PESSOA'),
#   (1396, 1401, 'I-PESSOA'),
#   (1410, 1415, 'B-PESSOA'),
#   (1416, 1422, 'I-PESSOA'),
#   (1423, 1427, 'I-PESSOA'),
#   (1436, 1439, 'B-PESSOA'),
#   (5292, 5295, 'I-LEGISLACAO'),
#   (5296, 5298, 'I-LEGISLACAO'),
#   (5299, 5304, 'I-LEGISLACAO'),
#   (5305, 5310, 'I-LEGISLACAO'),
#   (5416, 5419, 'B-LEGISLACAO'),
#   (5420, 5421, 'I-LEGISLACAO'),
#   (5422, 5425, 'I-LEGISLACAO'),
#   (5426, 5427, 'I-LEGISLACAO'),
#   (5428, 5429, 'I-LEGISLACAO'),
#   (5430, 5432, 'I-LEGISLACAO'),
#   (5433, 5435, 'I-LEGISLACAO'),
#   (5436, 5448, 'I-LEGISLACAO'),
#   (5449, 5456, 'I-LEGISLACAO'),
#   (5568, 5580, 'B-LEGISLACAO'),
#   (5944, 5952, 'B-ORGANIZACAO'),
#   (5953, 5960, 'I-ORGANIZACAO'),
#   (6180, 6188, 'B-ORGANIZACAO'),
#   (6189, 6196, 'I-ORGANIZACAO'),
#   (6222, 6231, 'B-ORGANIZACAO'),
#   (6232, 6242, 'I-ORGANIZACAO'),
#   (6295, 6300, 'B-PESSOA'),
#   (6301, 6303, 'I-PESSOA'),
#   (6304, 6309, 'I-PESSOA'),
#   (6334, 6337, 'B-JURISPRUDENCIA'),
#   (6338, 6340, 'I-JURISPRUDENCIA'),
#   (6341, 6347, 'I-JURISPRUDENCIA'),
#   (6363, 6366, 'B-LEGISLACAO'),
#   (6367, 6375, 'I-LEGISLACAO'),
#   (6376, 6378, 'I-LEGISLACAO'),
#   (6379, 6387, 'I-LEGISLACAO'),
#   (6388, 6395, 'I-LEGISLACAO'),
#   (6628, 6637, 'B-ORGANIZACAO'),
#   (6638, 6648, 'I-ORGANIZACAO'),
#   (6772, 6780, 'B-LOCAL'),
#   (6781, 6788, 'I-LOCAL'),
#   (7011, 7013, 'B-TEMPO'),
#   (7014, 7016, 'I-TEMPO'),
#   (7017, 7021, 'I-TEMPO'),
#   (7022, 7024, 'I-TEMPO'),
#   (7025, 7029, 'I-TEMPO'),
#   (7180, 7183, 'B-LEGISLACAO'),
#   (7184, 7192, 'I-LEGISLACAO'),
#   (7193, 7195, 'I-LEGISLACAO'),
#   (7196, 7204, 'I-LEGISLACAO'),
#   (7205, 7212, 'I-LEGISLACAO'),
#   (7425, 7432, 'B-ORGANIZACAO'),
#   (7433, 7441, 'I-ORGANIZACAO'),
#   (7442, 7449, 'I-ORGANIZACAO'),
#   (7455, 7458, 'B-JURISPRUDENCIA'),
#   (7459, 7462, 'I-JURISPRUDENCIA'),
#   (7463, 7472, 'I-JURISPRUDENCIA'),
#   (7506, 7514, 'B-ORGANIZACAO'),
#   (7515, 7517, 'I-ORGANIZACAO'),
#   (7518, 7525, 'I-ORGANIZACAO'),
#   (7526, 7528, 'I-ORGANIZACAO'),
#   (7529, 7537, 'I-ORGANIZACAO'),
#   (7538, 7545, 'I-ORGANIZACAO'),
#   (7546, 7547, 'I-ORGANIZACAO'),
#   (7548, 7551, 'I-ORGANIZACAO'),
#   (7552, 7563, 'I-ORGANIZACAO'),
#   (7648, 7651, 'B-LEGISLACAO'),
#   (7652, 7660, 'I-LEGISLACAO'),
#   (7661, 7663, 'I-LEGISLACAO'),
#   (7664, 7672, 'I-LEGISLACAO'),
#   (7673, 7680, 'I-LEGISLACAO'),
#   (7845, 7853, 'B-ORGANIZACAO'),
#   (7854, 7856, 'I-ORGANIZACAO'),
#   (7857, 7864, 'I-ORGANIZACAO'),
#   (7865, 7867, 'I-ORGANIZACAO'),
#   (7868, 7876, 'I-ORGANIZACAO'),
#   (7877, 7884, 'I-ORGANIZACAO'),
#   (7885, 7886, 'I-ORGANIZACAO'),
#   (7887, 7890, 'I-ORGANIZACAO'),
#   (7891, 7902, 'I-ORGANIZACAO'),
#   (7941, 7946, 'B-LEGISLACAO'),
#   (7947, 7952, 'I-LEGISLACAO'),
#   (8139, 8147, 'B-LOCAL'),
#   (8148, 8155, 'I-LOCAL'),
#   (8363, 8371, 'B-LOCAL'),
#   (8372, 8379, 'I-LOCAL'),
#   (8544, 8547, 'B-LEGISLACAO'),
#   (8548, 8550, 'I-LEGISLACAO'),
#   (8551, 8554, 'I-LEGISLACAO'),
#   (8560, 8562, 'B-TEMPO'),
#   (8563, 8565, 'I-TEMPO'),
#   (8566, 8572, 'I-TEMPO'),
#   (8573, 8575, 'I-TEMPO'),
#   (8576, 8580, 'I-TEMPO'),
#   (8611, 8619, 'B-PESSOA'),
#   (8620, 8629, 'I-PESSOA'),
#   (8674, 8682, 'B-LOCAL'),
#   (8683, 8690, 'I-LOCAL'),
#   (8751, 8755, 'B-LOCAL'),
#   (8756, 8758, 'I-LOCAL'),
#   (8759, 8767, 'I-LOCAL'),
#   (8768, 8774, 'I-LOCAL'),
#   (8775, 8777, 'I-LOCAL'),
#   (8778, 8785, 'I-LOCAL'),
#   (8813, 8819, 'B-ORGANIZACAO'),
#   (8820, 8831, 'I-ORGANIZACAO'),
#   (8832, 8834, 'I-ORGANIZACAO'),
#   (8835, 8843, 'I-ORGANIZACAO'),
#   (8844, 8851, 'I-ORGANIZACAO'),
#   (8888, 8889, 'B-LEGISLACAO'),
#   (8890, 8892, 'I-LEGISLACAO'),
#   (8893, 8895, 'I-LEGISLACAO'),
#   (8896, 8899, 'I-LEGISLACAO'),
#   (8900, 8901, 'I-LEGISLACAO'),
#   (8902, 8904, 'I-LEGISLACAO'),
#   (8905, 8907, 'I-LEGISLACAO'),
#   (8908, 8911, 'I-LEGISLACAO'),
#   (8912, 8920, 'I-LEGISLACAO'),
#   (8921, 8923, 'I-LEGISLACAO'),
#   (8924, 8932, 'I-LEGISLACAO'),
#   (8933, 8940, 'I-LEGISLACAO'),
#   (8945, 8948, 'B-LEGISLACAO'),
#   (8949, 8951, 'I-LEGISLACAO'),
#   (8952, 8955, 'I-LEGISLACAO'),
#   (8961, 8963, 'B-TEMPO'),
#   (8964, 8966, 'I-TEMPO'),
#   (8967, 8973, 'I-TEMPO'),
#   (8974, 8976, 'I-TEMPO'),
#   (8977, 8981, 'I-TEMPO'),
#   (9038, 9042, 'B-LOCAL'),
#   (9043, 9045, 'I-LOCAL'),
#   (9046, 9054, 'I-LOCAL'),
#   (9055, 9061, 'I-LOCAL'),
#   (9062, 9063, 'I-LOCAL'),
#   (9064, 9066, 'I-LOCAL'),
#   (9067, 9074, 'I-LOCAL'),
#   (9099, 9102, 'B-LEGISLACAO'),
#   (9103, 9105, 'I-LEGISLACAO'),
#   (9106, 9109, 'I-LEGISLACAO'),
#   (9115, 9117, 'B-TEMPO'),
#   (9118, 9120, 'I-TEMPO'),
#   (9121, 9129, 'I-TEMPO'),
#   (9130, 9132, 'I-TEMPO'),
#   (9133, 9137, 'I-TEMPO'),
#   (9193, 9197, 'B-LOCAL'),
#   (9198, 9205, 'I-LOCAL'),
#   (9427, 9434, 'B-LEGISLACAO'),
#   (9435, 9437, 'I-LEGISLACAO'),
#   (9438, 9444, 'I-LEGISLACAO'),
#   (9450, 9452, 'B-TEMPO'),
#   (9453, 9455, 'I-TEMPO'),
#   (9456, 9462, 'I-TEMPO'),
#   (9463, 9465, 'I-TEMPO'),
#   (9466, 9470, 'I-TEMPO'),
#   (9482, 9492, 'B-ORGANIZACAO'),
#   (9493, 9495, 'I-ORGANIZACAO'),
#   (9496, 9505, 'I-ORGANIZACAO'),
#   (9506, 9508, 'I-ORGANIZACAO'),
#   (9509, 9516, 'I-ORGANIZACAO'),
#   (9542, 9546, 'B-LOCAL'),
#   (9547, 9549, 'I-LOCAL'),
#   (9550, 9558, 'I-LOCAL'),
#   (9559, 9565, 'I-LOCAL'),
#   (9566, 9567, 'I-LOCAL'),
#   (9568, 9570, 'I-LOCAL'),
#   (9571, 9578, 'I-LOCAL'),
#   (9622, 9626, 'B-LOCAL'),
#   (9627, 9629, 'I-LOCAL'),
#   (9630, 9638, 'I-LOCAL'),
#   (9639, 9648, 'I-LOCAL'),
#   (9649, 9651, 'I-LOCAL'),
#   (9652, 9656, 'I-LOCAL'),
#   (9657, 9664, 'I-LOCAL'),
#   (9922, 9925, 'B-LEGISLACAO'),
#   (9926, 9928, 'I-LEGISLACAO'),
#   (9929, 9934, 'I-LEGISLACAO'),
#   (9940, 9942, 'B-TEMPO'),
#   (9943, 9945, 'I-TEMPO'),
#   (9946, 9951, 'I-TEMPO'),
#   (9952, 9954, 'I-TEMPO'),
#   (9955, 9959, 'I-TEMPO'),
#   (9992, 9996, 'B-PESSOA'),
#   (9997, 10002, 'I-PESSOA'),
#   (10089, 10095, 'B-LOCAL'),
#   (10096, 10110, 'I-LOCAL'),
#   (10111, 10113, 'I-LOCAL'),
#   (10114, 10121, 'I-LOCAL'),
#   (10122, 10124, 'B-LOCAL'),
#   (10125, 10128, 'I-LOCAL'),
#   (10148, 10154, 'B-ORGANIZACAO'),
#   (10155, 10166, 'I-ORGANIZACAO'),
#   (10167, 10169, 'I-ORGANIZACAO'),
#   (10170, 10178, 'I-ORGANIZACAO'),
#   (10179, 10186, 'I-ORGANIZACAO'),
#   (10213, 10221, 'B-LOCAL'),
#   (10222, 10229, 'I-LOCAL'),
#   (10246, 10247, 'B-LEGISLACAO'),
#   (14137, 14141, 'I-TEMPO'),
#   (14149, 14157, 'B-LEGISLACAO'),
#   (14158, 14161, 'I-LEGISLACAO'),
#   (14162, 14165, 'I-LEGISLACAO'),
#   (14171, 14172, 'B-TEMPO'),
#   (14173, 14175, 'I-TEMPO'),
#   (14176, 14183, 'I-TEMPO'),
#   (14184, 14186, 'I-TEMPO'),
#   (14187, 14191, 'I-TEMPO'),
#   (14203, 14212, 'B-ORGANIZACAO'),
#   (14213, 14223, 'I-ORGANIZACAO'),
#   (14224, 14226, 'I-ORGANIZACAO'),
#   (14227, 14237, 'I-ORGANIZACAO'),
#   (14238, 14246, 'I-ORGANIZACAO'),
#   (14249, 14253, 'B-ORGANIZACAO'),
#   (14261, 14270, 'B-ORGANIZACAO'),
#   (14271, 14273, 'I-ORGANIZACAO'),
#   (14274, 14284, 'I-ORGANIZACAO'),
#   (14285, 14294, 'I-ORGANIZACAO'),
#   (14295, 14296, 'I-ORGANIZACAO'),
#   (14297, 14306, 'I-ORGANIZACAO'),
#   (14307, 14315, 'I-ORGANIZACAO'),
#   (14318, 14323, 'B-ORGANIZACAO'),
#   (14349, 14355, 'B-LEGISLACAO'),
#   (14356, 14357, 'I-LEGISLACAO'),
#   (14358, 14361, 'I-LEGISLACAO'),
#   (14362, 14370, 'I-LEGISLACAO'),
#   (14371, 14374, 'I-LEGISLACAO'),
#   (14375, 14377, 'I-LEGISLACAO'),
#   (14383, 14385, 'B-TEMPO'),
#   (14386, 14388, 'I-TEMPO'),
#   (14389, 14397, 'I-TEMPO'),
#   (14398, 14400, 'I-TEMPO'),
#   (14401, 14405, 'I-TEMPO'),
#   (14416, 14424, 'B-TEMPO'),
#   (14490, 14498, 'B-ORGANIZACAO'),
#   (14499, 14506, 'I-ORGANIZACAO'),
#   (14522, 14528, 'B-ORGANIZACAO'),
#   (14529, 14540, 'I-ORGANIZACAO'),
#   (14659, 14667, 'B-LOCAL'),
#   (14668, 14675, 'I-LOCAL'),
#   (15014, 15022, 'B-ORGANIZACAO'),
#   (15023, 15030, 'I-ORGANIZACAO'),
#   (15492, 15500, 'B-ORGANIZACAO'),
#   (15501, 15508, 'I-ORGANIZACAO'),
#   (15826, 15834, 'B-LOCAL'),
#   (15835, 15842, 'I-LOCAL'),
#   (15944, 15952, 'B-ORGANIZACAO'),
#   (15953, 15960, 'I-ORGANIZACAO'),
#   (16014, 16017, 'B-LEGISLACAO'),
#   (16018, 16030, 'I-LEGISLACAO'),
#   (16031, 16033, 'I-LEGISLACAO'),
#   (16034, 16039, 'I-LEGISLACAO'),
#   (16092, 16095, 'B-LEGISLACAO'),
#   (16096, 16104, 'I-LEGISLACAO'),
#   (16105, 16107, 'I-LEGISLACAO'),
#   (16108, 16116, 'I-LEGISLACAO'),
#   (16117, 16124, 'I-LEGISLACAO'),
#   (16230, 16238, 'B-LOCAL'),
#   (16239, 16246, 'I-LOCAL'),
#   (16329, 16337, 'B-LOCAL'),
#   (16338, 16345, 'I-LOCAL'),
#   (16536, 16544, 'B-LOCAL'),
#   (16545, 16552, 'I-LOCAL'),
#   (16619, 16627, 'B-LOCAL'),
#   (16628, 16635, 'I-LOCAL'),
#   (16661, 16668, 'B-LEGISLACAO'),
#   (16669, 16671, 'I-LEGISLACAO'),
#   (16672, 16673, 'I-LEGISLACAO'),
#   (16674, 16680, 'I-LEGISLACAO'),
#   (16681, 16683, 'I-LEGISLACAO'),
#   (16684, 16685, 'I-LEGISLACAO'),
#   (16686, 16688, 'I-LEGISLACAO'),
#   (16689, 16690, 'I-LEGISLACAO'),
#   (16691, 16694, 'I-LEGISLACAO'),
#   (16695, 16696, 'I-LEGISLACAO'),
#   (16697, 16703, 'I-LEGISLACAO'),
#   (16704, 16706, 'I-LEGISLACAO'),
#   (16707, 16708, 'I-LEGISLACAO'),
#   (16709, 16711, 'I-LEGISLACAO'),
#   (16712, 16715, 'I-LEGISLACAO'),
#   (16716, 16724, 'I-LEGISLACAO'),
#   (16725, 16727, 'I-LEGISLACAO'),
#   (16728, 16736, 'I-LEGISLACAO'),
#   (16737, 16744, 'I-LEGISLACAO'),
#   (16809, 16812, 'B-LEGISLACAO'),
#   (16813, 16825, 'I-LEGISLACAO'),
#   (16826, 16828, 'I-LEGISLACAO'),
#   (16829, 16834, 'I-LEGISLACAO'),
#   (16862, 16868, 'B-ORGANIZACAO'),
#   (16869, 16880, 'I-ORGANIZACAO'),
#   (16881, 16883, 'I-ORGANIZACAO'),
#   (16884, 16892, 'I-ORGANIZACAO'),
#   (16893, 16900, 'I-ORGANIZACAO'),
#   (17125, 17128, 'B-LEGISLACAO'),
#   (17129, 17141, 'I-LEGISLACAO'),
#   (17142, 17151, 'I-LEGISLACAO'),
#   (17152, 17154, 'I-LEGISLACAO'),
#   (17155, 17157, 'I-LEGISLACAO'),
#   (17163, 17165, 'B-TEMPO'),
#   (17166, 17168, 'I-TEMPO'),
#   (17169, 17178, 'I-TEMPO'),
#   (17179, 17181, 'I-TEMPO'),
#   (17182, 17186, 'I-TEMPO'),
#   (17258, 17261, 'B-JURISPRUDENCIA'),
#   (17262, 17277, 'I-JURISPRUDENCIA'),
#   (17280, 17288, 'B-ORGANIZACAO'),
#   (17289, 17297, 'I-ORGANIZACAO'),
#   (17322, 17330, 'B-PESSOA'),
#   (17331, 17338, 'I-PESSOA'),
#   (17352, 17361, 'B-TEMPO'),
#   (17372, 17382, 'B-TEMPO'),
#   (17448, 17452, 'B-LEGISLACAO'),
#   (17453, 17467, 'I-LEGISLACAO'),
#   (17468, 17478, 'I-LEGISLACAO'),
#   (17479, 17481, 'I-LEGISLACAO'),
#   (17482, 17487, 'I-LEGISLACAO'),
#   (17490, 17495, 'B-LEGISLACAO'),
#   (17498, 17503, 'B-LEGISLACAO'),
#   (17506, 17511, 'B-LEGISLACAO'),
#   (17514, 17520, 'B-LEGISLACAO'),
#   (17523, 17529, 'B-LEGISLACAO'),
#   (17532, 17538, 'B-LEGISLACAO'),
#   (17541, 17547, 'B-LEGISLACAO'),
#   (17550, 17556, 'B-LEGISLACAO'),
#   (17559, 17565, 'B-LEGISLACAO'),
#   (17568, 17574, 'B-LEGISLACAO'),
#   (17577, 17583, 'B-LEGISLACAO'),
#   (17586, 17592, 'B-LEGISLACAO'),
#   (17595, 17601, 'B-LEGISLACAO'),
#   (17604, 17620, 'B-LEGISLACAO'),
#   (17888, 17896, 'B-LOCAL'),
#   (17897, 17904, 'I-LOCAL'),
#   (17958, 17961, 'B-LEGISLACAO'),
#   (17962, 17970, 'I-LEGISLACAO'),
#   (17971, 17973, 'I-LEGISLACAO'),
#   (17974, 17982, 'I-LEGISLACAO'),
#   (17983, 17990, 'I-LEGISLACAO'),
#   (18180, 18183, 'B-LEGISLACAO'),
#   (18184, 18185, 'I-LEGISLACAO'),
#   (18186, 18188, 'I-LEGISLACAO'),
#   (18189, 18191, 'I-LEGISLACAO'),
#   (18192, 18195, 'I-LEGISLACAO'),
#   (18196, 18198, 'I-LEGISLACAO'),
#   (18199, 18207, 'I-LEGISLACAO'),
#   (18240, 18243, 'B-JURISPRUDENCIA'),
#   (18244, 18259, 'I-JURISPRUDENCIA'),
#   (18262, 18270, 'B-ORGANIZACAO'),
#   (18271, 18279, 'I-ORGANIZACAO'),
#   (18304, 18310, 'B-PESSOA'),
#   (18311, 18322, 'I-PESSOA'),
#   (18336, 18345, 'B-TEMPO'),
#   (18356, 18366, 'B-TEMPO'),
#   (18466, 18469, 'B-LEGISLACAO'),
#   (18470, 18482, 'I-LEGISLACAO'),
#   (18483, 18492, 'I-LEGISLACAO'),
#   (18493, 18495, 'I-LEGISLACAO'),
#   (18496, 18499, 'I-LEGISLACAO'),
#   (18500, 18501, 'I-LEGISLACAO'),
#   (18502, 18504, 'I-LEGISLACAO'),
#   (18505, 18515, 'I-LEGISLACAO'),
#   (18581, 18594, 'B-LOCAL'),
#   (18597, 18599, 'B-LOCAL'),
#   (18600, 18602, 'I-LOCAL'),
#   (18668, 18671, 'B-LEGISLACAO'),
#   (18672, 18680, 'I-LEGISLACAO'),
#   (18681, 18683, 'I-LEGISLACAO'),
#   (18684, 18692, 'I-LEGISLACAO'),
#   (18693, 18700, 'I-LEGISLACAO'),
#   (18805, 18808, 'B-LEGISLACAO'),
#   (18809, 18821, 'I-LEGISLACAO'),
#   (18822, 18831, 'I-LEGISLACAO'),
#   (18832, 18834, 'I-LEGISLACAO'),
#   (18835, 18838, 'I-LEGISLACAO'),
#   (18844, 18846, 'B-TEMPO'),
#   (18847, 18849, 'I-TEMPO'),
#   (18850, 18858, 'I-TEMPO'),
#   (18859, 18861, 'I-TEMPO'),
#   (18862, 18866, 'I-TEMPO'),
#   (18972, 18985, 'B-LOCAL'),
#   (18986, 18992, 'B-LOCAL'),
#   (18993, 19007, 'I-LOCAL'),
#   (19008, 19010, 'I-LOCAL'),
#   (19157, 19165, 'B-LOCAL'),
#   (19166, 19173, 'I-LOCAL'),
#   (19331, 19334, 'B-JURISPRUDENCIA'),
#   (19335, 19350, 'I-JURISPRUDENCIA'),
#   (19353, 19361, 'B-ORGANIZACAO'),
#   (19362, 19370, 'I-ORGANIZACAO'),
#   (19395, 19399, 'B-PESSOA'),
#   (19400, 19406, 'I-PESSOA'),
#   (19420, 19429, 'B-TEMPO'),
#   (19440, 19449, 'B-TEMPO'),
#   (19508, 19516, 'B-ORGANIZACAO'),
#   (19517, 19524, 'I-ORGANIZACAO'),
#   (19576, 19583, 'B-LEGISLACAO'),
#   (19584, 19587, 'I-LEGISLACAO'),
#   (19588, 19599, 'I-LEGISLACAO'),
#   (19605, 19613, 'B-LEGISLACAO'),
#   (19614, 19617, 'I-LEGISLACAO'),
#   (19618, 19626, 'I-LEGISLACAO'),
#   (19632, 19641, 'B-ORGANIZACAO'),
#   (19642, 19652, 'I-ORGANIZACAO'),
#   (19653, 19655, 'I-ORGANIZACAO'),
#   (19656, 19666, 'I-ORGANIZACAO'),
#   (19667, 19676, 'I-ORGANIZACAO'),
#   (19677, 19678, 'I-ORGANIZACAO'),
#   (19679, 19688, 'I-ORGANIZACAO'),
#   (19689, 19697, 'I-ORGANIZACAO'),
#   (19698, 19703, 'B-ORGANIZACAO'),
#   (19837, 19845, 'B-LOCAL'),
#   (19846, 19853, 'I-LOCAL'),
#   (19882, 19888, 'B-ORGANIZACAO'),
#   (19889, 19900, 'I-ORGANIZACAO'),
#   (19956, 19962, 'B-LEGISLACAO'),
#   (19963, 19965, 'I-LEGISLACAO'),
#   (19966, 19967, 'I-LEGISLACAO'),
#   (19968, 19972, 'I-LEGISLACAO'),
#   (19973, 19975, 'I-LEGISLACAO'),
#   (19976, 19977, 'I-LEGISLACAO'),
#   (19978, 19980, 'I-LEGISLACAO'),
#   (19981, 19984, 'I-LEGISLACAO'),
#   (19985, 19993, 'I-LEGISLACAO'),
#   (19994, 19996, 'I-LEGISLACAO'),
#   (19997, 20005, 'I-LEGISLACAO'),
#   (20006, 20013, 'I-LEGISLACAO'),
#   (20068, 20076, 'B-ORGANIZACAO'),
#   (20077, 20084, 'I-ORGANIZACAO'),
#   (20133, 20141, 'B-LOCAL'),
#   (20259, 20266, 'B-LEGISLACAO'),
#   (20267, 20269, 'I-LEGISLACAO'),
#   (20270, 20276, 'I-LEGISLACAO'),
#   (20282, 20283, 'B-TEMPO'),
#   (20284, 20286, 'I-TEMPO'),
#   (20287, 20294, 'I-TEMPO'),
#   (20295, 20297, 'I-TEMPO'),
#   (20298, 20302, 'I-TEMPO'),
#   (20310, 20318, 'B-LEGISLACAO'),
#   (20319, 20320, 'I-LEGISLACAO'),
#   (20321, 20324, 'I-LEGISLACAO'),
#   (20330, 20332, 'B-TEMPO'),
#   (20333, 20335, 'I-TEMPO'),
#   (20336, 20343, 'I-TEMPO'),
#   (20344, 20346, 'I-TEMPO'),
#   (20347, 20351, 'I-TEMPO'),
#   (20363, 20372, 'B-ORGANIZACAO'),
#   (20373, 20383, 'I-ORGANIZACAO'),
#   (20384, 20386, 'I-ORGANIZACAO'),
#   (20387, 20397, 'I-ORGANIZACAO'),
#   (20398, 20406, 'I-ORGANIZACAO'),
#   (20407, 20411, 'B-ORGANIZACAO'),
#   (20419, 20428, 'B-ORGANIZACAO'),
#   (20429, 20431, 'I-ORGANIZACAO'),
#   (20432, 20442, 'I-ORGANIZACAO'),
#   (20443, 20452, 'I-ORGANIZACAO'),
#   (20453, 20454, 'I-ORGANIZACAO'),
#   (20455, 20464, 'I-ORGANIZACAO'),
#   (20465, 20473, 'I-ORGANIZACAO'),
#   (20474, 20480, 'B-ORGANIZACAO'),
#   (20550, 20558, 'B-LEGISLACAO'),
#   (20559, 20562, 'I-LEGISLACAO'),
#   (20563, 20571, 'I-LEGISLACAO'),
#   (20600, 20608, 'B-LOCAL'),
#   (20609, 20616, 'I-LOCAL'),
#   (20751, 20759, 'B-LOCAL'),
#   (20760, 20767, 'I-LOCAL'),
#   (20813, 20821, 'B-LOCAL'),
#   (20822, 20829, 'I-LOCAL'),
#   (20930, 20938, 'B-LOCAL'),
#   (20939, 20947, 'I-LOCAL'),
#   (20985, 20992, 'B-LEGISLACAO'),
#   (20993, 20996, 'I-LEGISLACAO'),
#   (20997, 21006, 'I-LEGISLACAO'),
#   (21033, 21036, 'B-LEGISLACAO'),
#   (21037, 21045, 'I-LEGISLACAO'),
#   (21046, 21048, 'I-LEGISLACAO'),
#   (21049, 21057, 'I-LEGISLACAO'),
#   (21058, 21065, 'I-LEGISLACAO'),
#   (21086, 21092, 'B-LEGISLACAO'),
#   (21093, 21096, 'I-LEGISLACAO'),
#   (21097, 21102, 'I-LEGISLACAO'),
#   (21111, 21117, 'B-LEGISLACAO'),
#   (21118, 21121, 'I-LEGISLACAO'),
#   (21122, 21123, 'I-LEGISLACAO'),
#   (21124, 21128, 'I-LEGISLACAO'),
#   (21129, 21131, 'I-LEGISLACAO'),
#   (21132, 21133, 'I-LEGISLACAO'),
#   (21134, 21136, 'I-LEGISLACAO'),
#   (21137, 21141, 'I-LEGISLACAO'),
#   (21197, 21205, 'B-LOCAL'),
#   (21206, 21213, 'I-LOCAL'),
#   (21292, 21300, 'B-LOCAL'),
#   (21301, 21308, 'I-LOCAL'),
#   (21325, 21332, 'B-LEGISLACAO'),
#   (21333, 21336, 'I-LEGISLACAO'),
#   (21337, 21346, 'I-LEGISLACAO'),
#   (21351, 21359, 'B-LEGISLACAO'),
#   (21360, 21363, 'I-LEGISLACAO'),
#   (21364, 21370, 'I-LEGISLACAO'),
#   (21376, 21381, 'B-ORGANIZACAO'),
#   (21526, 21529, 'B-LEGISLACAO'),
#   (21530, 21531, 'I-LEGISLACAO'),
#   (21532, 21534, 'I-LEGISLACAO'),
#   (21535, 21536, 'I-LEGISLACAO'),
#   (21537, 21539, 'I-LEGISLACAO'),
#   (21540, 21544, 'I-LEGISLACAO'),
#   (21742, 21750, 'B-LOCAL'),
#   (21751, 21758, 'I-LOCAL'),
#   (21931, 21935, 'B-LEGISLACAO'),
#   (21936, 21946, 'I-LEGISLACAO'),
#   (21947, 21950, 'I-LEGISLACAO'),
#   (21951, 21954, 'I-LEGISLACAO'),
#   (21960, 21962, 'B-TEMPO'),
#   (21963, 21965, 'I-TEMPO'),
#   (21966, 21972, 'I-TEMPO'),
#   (21973, 21975, 'I-TEMPO'),
#   (21976, 21980, 'I-TEMPO'),
#   (21985, 21990, 'B-LEGISLACAO'),
#   (21996, 21998, 'B-TEMPO'),
#   (21999, 22001, 'I-TEMPO'),
#   (22002, 22007, 'I-TEMPO'),
#   (22008, 22010, 'I-TEMPO'),
#   (22011, 22015, 'I-TEMPO'),
#   (22023, 22026, 'B-LEGISLACAO'),
#   (22027, 22039, 'I-LEGISLACAO'),
#   (22040, 22049, 'I-LEGISLACAO'),
#   (22050, 22053, 'I-LEGISLACAO'),
#   (22054, 22057, 'I-LEGISLACAO'),
#   (22063, 22064, 'B-TEMPO'),
#   (22065, 22067, 'I-TEMPO'),
#   (22068, 22073, 'I-TEMPO'),
#   (22074, 22076, 'I-TEMPO'),
#   (22077, 22081, 'I-TEMPO'),
#   (22118, 22122, 'B-PESSOA'),
#   (22123, 22130, 'I-PESSOA'),
#   (22233, 22245, 'B-LEGISLACAO'),
#   (22246, 22248, 'I-LEGISLACAO'),
#   (22249, 22253, 'I-LEGISLACAO'),
#   (22431, 22439, 'B-ORGANIZACAO'),
#   (22440, 22447, 'I-ORGANIZACAO'),
#   (22613, 22618, 'B-PESSOA'),
#   (22619, 22621, 'I-PESSOA'),
#   (22622, 22627, 'I-PESSOA'),
#   (23514, 23520, 'B-ORGANIZACAO'),
#   (23521, 23532, 'I-ORGANIZACAO'),
#   (23551, 23559, 'B-LOCAL'),
#   (23560, 23567, 'I-LOCAL'),
#   (23634, 23641, 'B-ORGANIZACAO'),
#   (23815, 23818, 'B-LEGISLACAO'),
#   (23819, 23827, 'I-LEGISLACAO'),
#   (23828, 23830, 'I-LEGISLACAO'),
#   (23831, 23839, 'I-LEGISLACAO'),
#   (23840, 23847, 'I-LEGISLACAO'),
#   (24002, 24010, 'B-ORGANIZACAO'),
#   (24011, 24018, 'I-ORGANIZACAO'),
#   (24082, 24092, 'B-ORGANIZACAO'),
#   (24093, 24100, 'I-ORGANIZACAO'),
#   (24131, 24141, 'B-ORGANIZACAO'),
#   (24142, 24149, 'I-ORGANIZACAO'),
#   (24160, 24168, 'B-ORGANIZACAO'),
#   (24169, 24176, 'I-ORGANIZACAO'),
#   (24599, 24604, 'B-PESSOA'),
#   (24605, 24607, 'I-PESSOA'),
#   (24608, 24616, 'I-PESSOA'),
#   (24680, 24684, 'B-PESSOA'),
#   (24685, 24692, 'I-PESSOA'),
#   (24881, 24886, 'B-PESSOA'),
#   (24887, 24893, 'I-PESSOA'),
#   (24995, 25003, 'B-LOCAL'),
#   (25004, 25011, 'I-LOCAL'),
#   (25076, 25080, 'B-LEGISLACAO'),
#   (25081, 25091, 'I-LEGISLACAO'),
#   (25092, 25094, 'I-LEGISLACAO'),
#   (25095, 25098, 'I-LEGISLACAO'),
#   (25104, 25106, 'B-TEMPO'),
#   (25107, 25109, 'I-TEMPO'),
#   (25110, 25116, 'I-TEMPO'),
#   (25117, 25119, 'I-TEMPO'),
#   (25120, 25124, 'I-TEMPO'),
#   (25129, 25131, 'B-LEGISLACAO'),
#   (25132, 25137, 'I-LEGISLACAO'),
#   (25143, 25145, 'B-TEMPO'),
#   (25146, 25148, 'I-TEMPO'),
#   (25149, 25154, 'I-TEMPO'),
#   (25155, 25157, 'I-TEMPO'),
#   (25158, 25162, 'I-TEMPO'),
#   (25177, 25180, 'B-LEGISLACAO'),
#   (25181, 25193, 'I-LEGISLACAO'),
#   (25194, 25196, 'I-LEGISLACAO'),
#   (25197, 25200, 'I-LEGISLACAO'),
#   (25206, 25207, 'B-TEMPO'),
#   (25208, 25210, 'I-TEMPO'),
#   ...]}

# %%
conteudo.find('Conselho Especial')
# Out:
# 8

# %%
conteudo.find('Conselho Especial') + len('Conselho Especial')
# Out:
# 25

# %% [markdown]
# ### Transformando todos os dados

# %%
arquivos = grupo_arquivos.groups.keys()

# %%
arquivos
# Out:
# dict_keys(['AC1TCU.txt', 'AC1TJAC.txt', 'AC1TJMG.txt', 'AC2.txt', 'ACORDAOTCU25052016.txt', 'ADI2TJDFT.txt', 'AIAgRAgI6193ARAGUARIMG.txt', 'AIRR15708820115050222.txt', 'AIRR3999520145020086.txt', 'AP00000794920137060006.txt', 'AP00001415620157010201.txt', 'AP00001441420167030203.txt', 'AP771420167080008PA.txt', 'Ag10000170733596001.txt', 'Ag10105170208398001.txt', 'AgAIRR11889820145030011.txt', 'AgCr10582160008758001.txt', 'AgRgSTJ1.txt', 'AgRgSTJ2.txt', 'AgRgTSE1.txt', 'AgRgTSE3.txt', 'CP32320177080008PA.txt', 'DespSEPLAGDF.txt', 'ED1STM.txt', 'ED1TJAC.txt', 'EDAgRgTSE2.txt', 'EDEDARR208420135040232.txt', 'EDRR1TST.txt', 'EEDRR9715120105020002.txt', 'ERR731004520105130003.txt', 'HC110260SP.txt', 'HC151914AgRES.txt', 'HC340624SP.txt', 'HC418951PR.txt', 'HC70000845920187000000.txt', 'Lei11788.txt', 'LoaDF2018.txt', 'Pet128TSE5.txt', 'Port77DF.txt', 'REE5908TSE4.txt', 'REsp1583083RS.txt', 'RR2574407120025020372.txt', 'RR474820145230056.txt', 'RR942006420095040028.txt', 'Rcl3495STJ.txt', 'TCU4687.txt', 'TSTRR16037920105200001.txt', 'adi3767.txt', 'airr801422012.txt', 'lei11340.txt'])

# %%
documentos = []
for arquivo in arquivos:
    tabela_agrupada = grupo_arquivos.get_group(arquivo)[['palavra', 'label']].values
    conteudo = ''
    anotacoes = {'entities': []}
    inicio_palavra = 0
    fim_palavra = 0

    for texto, label in tabela_agrupada:
        texto = str(texto)
        tamanho_texto = len(texto) + 1

        inicio_palavra = fim_palavra
        fim_palavra = inicio_palavra + tamanho_texto

        if label != 'O':
            anotacao = (inicio_palavra, fim_palavra - 1, label)
            anotacoes['entities'].append(anotacao)

        conteudo = conteudo + texto + ' '

    documento = (conteudo, anotacoes)
    documentos.append(documento)

# %%
documentos[0]
# Out:
FICATIVA DO PREGOEIRO . MULTA . ARQUIVAMENTO . Acórdão VISTOS , relatados e discutidos estes autos de denúncia sobre irregularidades no pregão eletrônico 25/2016 conduzido pelo Comando da Aeronáutica - Grupamento de Apoio de Brasília , com vistas à contratação de empresa especializada em prestação de serviços de transporte de bagagem desacompanhada de militar movimentado no âmbito do território nacional , ACORDAM os Ministros do Tribunal de Contas da União , reunidos em sessão do Plenário , diante das razões expostas pelo Relator , em : 9.1. rejeitar as razões de justificativas apresentadas por André Luiz Moreira da Silva ; 9.2. com fundamento no art . 58 , inciso II , da Lei 8.443/1992 , aplicar a André Luiz Moreira da Silva multa no valor de R $ 5.000,00 ( cinco mil reais ) , atualizado monetariamente desde a data do presente acórdão até a do efetivo recolhimento , se for pago após o vencimento , na forma da legislação vigente , fixando o prazo de 15 ( quinze ) dias , a contar do recebimento da notificação , para que seja comprovado , perante este Tribunal , o recolhimento da quantia ao Tesouro Nacional , nos termos do art . 23 , inciso III , alínea “ a ” , da referida Lei , c/c o art . 214 , inciso III , alínea “ a ” , do Regimento Interno do TCU ; 9.3. com fundamento no art . 26 da Lei 8.443/1992 , autorizar , se requerido , o pagamento da importância devida em até 36 ( trinta e seis ) parcelas mensais e consecutivas , fixando o prazo de 1 ...
#  {'entities': [(18, 25, 'B-JURISPRUDENCIA'),
#    (26, 35, 'I-JURISPRUDENCIA'),
#    (38, 46, 'B-ORGANIZACAO'),
#    (55, 60, 'B-PESSOA'),
#    (61, 67, 'I-PESSOA'),
#    (68, 76, 'B-JURISPRUDENCIA'),
#    (77, 91, 'I-JURISPRUDENCIA'),
#    (141, 151, 'B-TEMPO'),
#    (301, 304, 'B-LEGISLACAO'),
#    (305, 306, 'I-LEGISLACAO'),
#    (307, 309, 'I-LEGISLACAO'),
#    (310, 311, 'I-LEGISLACAO'),
#    (312, 317, 'I-LEGISLACAO'),
#    (318, 319, 'I-LEGISLACAO'),
#    (320, 322, 'I-LEGISLACAO'),
#    (323, 326, 'I-LEGISLACAO'),
#    (327, 337, 'I-LEGISLACAO'),
#    (362, 367, 'B-PESSOA'),
#    (368, 372, 'I-PESSOA'),
#    (373, 380, 'I-PESSOA'),
#    (381, 383, 'I-PESSOA'),
#    (384, 389, 'I-PESSOA'),
#    (431, 438, 'B-ORGANIZACAO'),
#    (439, 447, 'I-ORGANIZACAO'),
#    (448, 450, 'I-ORGANIZACAO'),
#    (451, 462, 'I-ORGANIZACAO'),
#    (463, 468, 'I-ORGANIZACAO'),
#    (503, 510, 'B-ORGANIZACAO'),
#    (511, 513, 'I-ORGANIZACAO'),
#    (514, 525, 'I-ORGANIZACAO'),
#    (579, 589, 'B-ORGANIZACAO'),
#    (590, 597, 'I-ORGANIZACAO'),
#    (610, 617, 'B-ORGANIZACAO'),
#    (618, 625, 'I-ORGANIZACAO'),
#    (626, 636, 'I-ORGANIZACAO'),
#    (637, 639, 'I-ORGANIZACAO'),
#    (640, 648, 'I-ORGANIZACAO'),
#    (649, 656, 'I-ORGANIZACAO'),
#    (657, 659, 'I-ORGANIZACAO'),
#    (660, 670, 'I-ORGANIZACAO'),
#    (671, 681, 'I-ORGANIZACAO'),
#    (684, 689, 'B-ORGANIZACAO'),
#    (720, 725, 'B-PESSOA'),
#    (726, 732, 'I-PESSOA'),
#    (733, 738, 'I-PESSOA'),
#    (783, 790, 'B-ORGANIZACAO'),
#    (791, 793, 'I-ORGANIZACAO'),
#    (794, 805, 'I-ORGANIZACAO'),
#    (808, 818, 'B-ORGANIZACAO'),
#    (819, 821, 'I-ORGANIZACAO'),
#    (822, 827, 'I-ORGANIZACAO'),
#    (828, 830, 'I-ORGANIZACAO'),
#    (831, 839, 'I-ORGANIZACAO'),
#    (848, 853, 'B-PESSOA'),
#    (854, 862, 'I-PESSOA'),
#    (863, 869, 'I-PESSOA'),
#    (870, 874, 'I-PESSOA'),
#    (875, 882, 'I-PESSOA'),
#    (918, 925, 'B-ORGANIZACAO'),
#    (926, 934, 'I-ORGANIZACAO'),
#    (935, 937, 'I-ORGANIZACAO'),
#    (938, 949, 'I-ORGANIZACAO'),
#    (950, 954, 'I-ORGANIZACAO'),
#    (1032, 1039, 'B-ORGANIZACAO'),
#    (1040, 1042, 'I-ORGANIZACAO'),
#    (1043, 1054, 'I-ORGANIZACAO'),
#    (1057, 1067, 'B-ORGANIZACAO'),
#    (1068, 1070, 'I-ORGANIZACAO'),
#    (1071, 1076, 'I-ORGANIZACAO'),
#    (1077, 1079, 'I-ORGANIZACAO'),
#    (1080, 1088, 'I-ORGANIZACAO'),
#    (1790, 1797, 'B-JURISPRUDENCIA'),
#    (1798, 1821, 'I-JURISPRUDENCIA'),
#    (1853, 1863, 'B-TEMPO'),
#    (2708, 2715, 'B-ORGANIZACAO'),
#    (2716, 2718, 'I-ORGANIZACAO'),
#    (2719, 2730, 'I-ORGANIZACAO'),
#    (2733, 2743, 'B-ORGANIZACAO'),
#    (2744, 2746, 'I-ORGANIZACAO'),
#    (2747, 2752, 'I-ORGANIZACAO'),
#    (2753, 2755, 'I-ORGANIZACAO'),
#    (2756, 2764, 'I-ORGANIZACAO'),
#    (2964, 2972, 'B-ORGANIZACAO'),
#    (2973, 2975, 'I-ORGANIZACAO'),
#    (2976, 2982, 'I-ORGANIZACAO'),
#    (2983, 2985, 'I-ORGANIZACAO'),
#    (2986, 2991, 'I-ORGANIZACAO'),
#    (3016, 3024, 'B-ORGANIZACAO'),
#    (3133, 3138, 'B-PESSOA'),
#    (3139, 3143, 'I-PESSOA'),
#    (3144, 3151, 'I-PESSOA'),
#    (3152, 3154, 'I-PESSOA'),
#    (3155, 3160, 'I-PESSOA'),
#    (3186, 3189, 'B-LEGISLACAO'),
#    (3190, 3191, 'I-LEGISLACAO'),
#    (3192, 3194, 'I-LEGISLACAO'),
#    (3195, 3196, 'I-LEGISLACAO'),
#    (3197, 3203, 'I-LEGISLACAO'),
#    (3204, 3206, 'I-LEGISLACAO'),
#    (3207, 3208, 'I-LEGISLACAO'),
#    (3209, 3211, 'I-LEGISLACAO'),
#    (4691, 4692, 'I-LEGISLACAO'),
#    (4693, 4699, 'I-LEGISLACAO'),
#    (4700, 4701, 'I-LEGISLACAO'),
#    (4702, 4703, 'I-LEGISLACAO'),
#    (4704, 4706, 'I-LEGISLACAO'),
#    (4707, 4710, 'I-LEGISLACAO'),
#    (4711, 4721, 'I-LEGISLACAO'),
#    (4747, 4750, 'B-LEGISLACAO'),
#    (4751, 4752, 'I-LEGISLACAO'),
#    (4753, 4755, 'I-LEGISLACAO'),
#    (4756, 4758, 'I-LEGISLACAO'),
#    (4759, 4762, 'I-LEGISLACAO'),
#    (4763, 4773, 'I-LEGISLACAO'),
#    (4921, 4928, 'B-JURISPRUDENCIA'),
#    (4929, 4952, 'I-JURISPRUDENCIA'),
#    (4974, 4981, 'B-ORGANIZACAO'),
#    (4982, 4984, 'I-ORGANIZACAO'),
#    (4985, 4996, 'I-ORGANIZACAO'),
#    (4999, 5009, 'B-ORGANIZACAO'),
#    (5010, 5012, 'I-ORGANIZACAO'),
#    (5013, 5018, 'I-ORGANIZACAO'),
#    (5019, 5021, 'I-ORGANIZACAO'),
#    (5022, 5030, 'I-ORGANIZACAO'),
#    (5077, 5087, 'B-ORGANIZACAO'),
#    (5088, 5090, 'I-ORGANIZACAO'),
#    (5091, 5099, 'I-ORGANIZACAO'),
#    (5100, 5107, 'I-ORGANIZACAO'),
#    (5108, 5110, 'I-ORGANIZACAO'),
#    (5111, 5121, 'I-ORGANIZACAO'),
#    (5122, 5132, 'I-ORGANIZACAO'),
#    (5264, 5271, 'B-ORGANIZACAO'),
#    (5272, 5274, 'I-ORGANIZACAO'),
#    (5275, 5286, 'I-ORGANIZACAO'),
#    (5289, 5299, 'B-ORGANIZACAO'),
#    (5300, 5302, 'I-ORGANIZACAO'),
#    (5303, 5308, 'I-ORGANIZACAO'),
#    (5309, 5311, 'I-ORGANIZACAO'),
#    (5312, 5320, 'I-ORGANIZACAO'),
#    (5351, 5363, 'B-LEGISLACAO'),
#    (5364, 5370, 'I-LEGISLACAO'),
#    (5606, 5613, 'B-JURISPRUDENCIA'),
#    (5614, 5637, 'I-JURISPRUDENCIA'),
#    (5650, 5659, 'B-ORGANIZACAO'),
#    (5660, 5665, 'I-ORGANIZACAO'),
#    (5666, 5672, 'I-ORGANIZACAO'),
#    (5673, 5675, 'I-ORGANIZACAO'),
#    (5676, 5687, 'I-ORGANIZACAO'),
#    (5688, 5690, 'I-ORGANIZACAO'),
#    (5691, 5705, 'I-ORGANIZACAO'),
#    (5711, 5721, 'B-ORGANIZACAO'),
#    (5722, 5724, 'I-ORGANIZACAO'),
#    (5725, 5740, 'I-ORGANIZACAO'),
#    (5741, 5747, 'I-ORGANIZACAO'),
#    (5748, 5749, 'I-ORGANIZACAO'),
#    (5750, 5757, 'I-ORGANIZACAO'),
#    (5758, 5759, 'I-ORGANIZACAO'),
#    (5760, 5764, 'I-ORGANIZACAO'),
#    (5866, 5873, 'B-ORGANIZACAO'),
#    (5874, 5876, 'I-ORGANIZACAO'),
#    (13821, 13825, 'B-ORGANIZACAO'),
#    (13831, 13842, 'B-LOCAL'),
#    (14049, 14056, 'B-JURISPRUDENCIA'),
#    (14057, 14067, 'I-JURISPRUDENCIA'),
#    (14070, 14073, 'B-ORGANIZACAO'),
#    (14076, 14084, 'B-ORGANIZACAO'),
#    (14111, 14117, 'B-ORGANIZACAO'),
#    (14154, 14163, 'B-ORGANIZACAO'),
#    (14164, 14169, 'I-ORGANIZACAO'),
#    (14170, 14176, 'I-ORGANIZACAO'),
#    (14312, 14322, 'B-TEMPO'),
#    (14351, 14354, 'B-ORGANIZACAO'),
#    (14367, 14374, 'B-JURISPRUDENCIA'),
#    (14375, 14385, 'I-JURISPRUDENCIA'),
#    (14388, 14391, 'B-ORGANIZACAO'),
#    (14465, 14475, 'B-ORGANIZACAO'),
#    (14476, 14478, 'I-ORGANIZACAO'),
#    (14479, 14494, 'I-ORGANIZACAO'),
#    (14495, 14501, 'I-ORGANIZACAO'),
#    (14502, 14503, 'I-ORGANIZACAO'),
#    (14504, 14511, 'I-ORGANIZACAO'),
#    (14512, 14513, 'I-ORGANIZACAO'),
#    (14514, 14518, 'I-ORGANIZACAO'),
#    (14666, 14675, 'B-TEMPO'),
#    (14842, 14849, 'B-JURISPRUDENCIA'),
#    (14850, 14860, 'I-JURISPRUDENCIA'),
#    (14863, 14866, 'B-ORGANIZACAO'),
#    (14869, 14877, 'B-ORGANIZACAO'),
#    (14981, 14987, 'B-ORGANIZACAO'),
#    (15265, 15274, 'B-TEMPO'),
#    (15455, 15465, 'B-TEMPO'),
#    (15492, 15499, 'B-JURISPRUDENCIA'),
#    (15500, 15510, 'I-JURISPRUDENCIA'),
#    (15513, 15516, 'B-ORGANIZACAO'),
#    (15519, 15527, 'B-ORGANIZACAO'),
#    (15916, 15925, 'B-LEGISLACAO'),
#    (15926, 15935, 'I-LEGISLACAO'),
#    (15936, 15942, 'I-LEGISLACAO'),
#    (15943, 15952, 'I-LEGISLACAO'),
#    (15980, 15982, 'B-TEMPO'),
#    (15983, 15985, 'I-TEMPO'),
#    (15986, 15991, 'I-TEMPO'),
#    (15992, 15994, 'I-TEMPO'),
#    (15995, 15999, 'I-TEMPO'),
#    (16013, 16014, 'B-LEGISLACAO'),
#    (16015, 16017, 'I-LEGISLACAO'),
#    (16018, 16020, 'I-LEGISLACAO'),
#    (16021, 16024, 'I-LEGISLACAO'),
#    (16025, 16026, 'I-LEGISLACAO'),
#    (16027, 16029, 'I-LEGISLACAO'),
#    (16030, 16032, 'I-LEGISLACAO'),
#    (16033, 16035, 'I-LEGISLACAO'),
#    (16036, 16042, 'I-LEGISLACAO'),
#    (16100, 16106, 'B-ORGANIZACAO'),
#    (16107, 16109, 'I-ORGANIZACAO'),
#    (16110, 16116, 'I-ORGANIZACAO'),
#    (16339, 16346, 'B-JURISPRUDENCIA'),
#    (16347, 16357, 'I-JURISPRUDENCIA'),
#    (16360, 16363, 'B-ORGANIZACAO'),
#    (16366, 16374, 'B-ORGANIZACAO'),
#    (21606, 21611, 'B-ORGANIZACAO'),
#    (21788, 21794, 'B-ORGANIZACAO'),
#    (22000, 22008, 'B-ORGANIZACAO'),
#    (22117, 22123, 'B-ORGANIZACAO'),
#    (22321, 22330, 'B-ORGANIZACAO'),
#    (22331, 22336, 'I-ORGANIZACAO'),
#    (22337, 22343, 'I-ORGANIZACAO'),
#    (22344, 22346, 'I-ORGANIZACAO'),
#    (22347, 22358, 'I-ORGANIZACAO'),
#    (22359, 22361, 'I-ORGANIZACAO'),
#    (22362, 22376, 'I-ORGANIZACAO'),
#    (22458, 22466, 'B-TEMPO'),
#    (22469, 22477, 'B-TEMPO'),
#    (22686, 22693, 'B-JURISPRUDENCIA'),
#    (22694, 22704, 'I-JURISPRUDENCIA'),
#    (22707, 22710, 'B-ORGANIZACAO'),
#    (22713, 22721, 'B-ORGANIZACAO'),
#    (22748, 22754, 'B-ORGANIZACAO'),
#    (22811, 22820, 'B-ORGANIZACAO'),
#    (22821, 22826, 'I-ORGANIZACAO'),
#    (22827, 22833, 'I-ORGANIZACAO'),
#    (22972, 22979, 'B-JURISPRUDENCIA'),
#    (22980, 22990, 'I-JURISPRUDENCIA'),
#    (22993, 22996, 'B-ORGANIZACAO'),
#    (22999, 23007, 'B-ORGANIZACAO'),
#    (23093, 23099, 'B-ORGANIZACAO'),
#    (23331, 23340, 'B-LEGISLACAO'),
#    (23341, 23350, 'I-LEGISLACAO'),
#    (23351, 23357, 'I-LEGISLACAO'),
#    (23358, 23367, 'B-ORGANIZACAO'),
#    (23472, 23478, 'B-ORGANIZACAO'),
#    (23479, 23481, 'I-ORGANIZACAO'),
#    (23482, 23488, 'I-ORGANIZACAO'),
#    (23657, 23662, 'B-PESSOA'),
#    (23663, 23667, 'I-PESSOA'),
#    (23668, 23675, 'I-PESSOA'),
#    (23676, 23678, 'I-PESSOA'),
#    (23679, 23684, 'I-PESSOA'),
#    (23820, 23826, 'B-LEGISLACAO'),
#    (23827, 23829, 'I-LEGISLACAO'),
#    (23830, 23832, 'I-LEGISLACAO'),
#    (23833, 23836, 'I-LEGISLACAO'),
#    (23837, 23838, 'I-LEGISLACAO'),
#    (23839, 23841, 'I-LEGISLACAO'),
#    (23842, 23844, 'I-LEGISLACAO'),
#    (23845, 23848, 'I-LEGISLACAO'),
#    (23849, 23859, 'I-LEGISLACAO'),
#    (23944, 23951, 'B-JURISPRUDENCIA'),
#    (23952, 23962, 'I-JURISPRUDENCIA'),
#    (23965, 23968, 'B-ORGANIZACAO'),
#    (23971, 23979, 'B-ORGANIZACAO'),
#    (24254, 24259, 'B-PESSOA'),
#    (24260, 24264, 'I-PESSOA'),
#    (24265, 24272, 'I-PESSOA'),
#    (24273, 24275, 'I-PESSOA'),
#    (24276, 24281, 'I-PESSOA'),
#    (24476, 24482, 'B-LEGISLACAO'),
#    (24483, 24485, 'I-LEGISLACAO'),
#    (24486, 24488, 'I-LEGISLACAO'),
#    (24489, 24492, 'I-LEGISLACAO'),
#    (24493, 24494, 'I-LEGISLACAO'),
#    (25471, 25473, 'I-LEGISLACAO'),
#    (25474, 25477, 'I-LEGISLACAO'),
#    (25478, 25488, 'I-LEGISLACAO'),
#    (25690, 25697, 'B-JURISPRUDENCIA'),
#    (25698, 25709, 'I-JURISPRUDENCIA'),
#    (25712, 25715, 'B-ORGANIZACAO'),
#    (25718, 25726, 'B-ORGANIZACAO'),
#    (25748, 25754, 'B-ORGANIZACAO'),
#    (25785, 25794, 'B-LEGISLACAO'),
#    (25795, 25804, 'I-LEGISLACAO'),
#    (25805, 25811, 'I-LEGISLACAO'),
#    (25812, 25821, 'I-LEGISLACAO'),
#    (25926, 25932, 'B-ORGANIZACAO'),
#    (25933, 25935, 'I-ORGANIZACAO'),
#    (25936, 25942, 'I-ORGANIZACAO'),
#    (26108, 26115, 'B-JURISPRUDENCIA'),
#    (26116, 26126, 'I-JURISPRUDENCIA'),
#    (26129, 26132, 'B-ORGANIZACAO'),
#    (26135, 26143, 'B-ORGANIZACAO'),
#    (26162, 26171, 'B-ORGANIZACAO'),
#    (26172, 26177, 'I-ORGANIZACAO'),
#    (26178, 26184, 'I-ORGANIZACAO'),
#    (26185, 26187, 'I-ORGANIZACAO'),
#    (26188, 26199, 'I-ORGANIZACAO'),
#    (26200, 26202, 'I-ORGANIZACAO'),
#    (26203, 26217, 'I-ORGANIZACAO'),
#    (26369, 26379, 'B-TEMPO'),
#    (26408, 26411, 'B-ORGANIZACAO'),
#    (26424, 26431, 'B-JURISPRUDENCIA'),
#    (26432, 26442, 'I-JURISPRUDENCIA'),
#    (26445, 26448, 'B-ORGANIZACAO'),
#    (26510, 26517, 'B-JURISPRUDENCIA'),
#    (26518, 26528, 'I-JURISPRUDENCIA'),
#    (26531, 26534, 'B-ORGANIZACAO'),
#    (26537, 26545, 'B-ORGANIZACAO'),
#    (26638, 26644, 'B-ORGANIZACAO'),
#    (26787, 26794, 'B-ORGANIZACAO'),
#    (26795, 26797, 'I-ORGANIZACAO'),
#    (26798, 26809, 'I-ORGANIZACAO'),
#    (26812, 26822, 'B-ORGANIZACAO'),
#    (26823, 26825, 'I-ORGANIZACAO'),
#    (26826, 26831, 'I-ORGANIZACAO'),
#    (26832, 26834, 'I-ORGANIZACAO'),
#    (26835, 26843, 'I-ORGANIZACAO'),
#    (26846, 26852, 'B-ORGANIZACAO'),
#    (27197, 27202, 'B-PESSOA'),
#    (27203, 27207, 'I-PESSOA'),
#    (27208, 27210, 'I-PESSOA'),
#    (27211, 27219, 'I-PESSOA'),
#    (27335, 27342, 'B-JURISPRUDENCIA'),
#    (27343, 27366, 'I-JURISPRUDENCIA'),
#    (27392, 27402, 'B-TEMPO'),
#    (27834, 27840, 'B-ORGANIZACAO'),
#    (28071, 28081, 'B-TEMPO'),
#    (28111, 28117, 'B-ORGANIZACAO'),
#    (28282, 28287, 'B-PESSOA'),
#    (28288, 28292, 'I-PESSOA'),
#    (28293, 28300, 'I-PESSOA'),
#    (28301, 28303, 'I-PESSOA'),
#    (28304, 28309, 'I-PESSOA'),
#    (29015, 29020, 'B-PESSOA'),
#    (29021, 29025, 'I-PESSOA'),
#    (29026, 29033, 'I-PESSOA'),
#    (29034, 29036, 'I-PESSOA'),
#    (29037, 29042, 'I-PESSOA'),
#    (29328, 29335, 'B-JURISPRUDENCIA'),
#    (29336, 29359, 'I-JURISPRUDENCIA'),
#    (29475, 29483, 'B-ORGANIZACAO'),
#    (29552, 29561, 'B-ORGANIZACAO'),
#    (29562, 29567, 'I-ORGANIZACAO'),
#    (29568, 29574, 'I-ORGANIZACAO'),
#    (29575, 29577, 'I-ORGANIZACAO'),
#    (29578, 29589, 'I-ORGANIZACAO'),
#    (29590, 29592, 'I-ORGANIZACAO'),
#    (29593, 29607, 'I-ORGANIZACAO'),
#    (29679, 29689, 'B-ORGANIZACAO'),
#    (29690, 29692, 'I-ORGANIZACAO'),
#    (29693, 29708, 'I-ORGANIZACAO'),
#    (29709, 29715, 'I-ORGANIZACAO'),
#    (29716, 29717, 'I-ORGANIZACAO'),
#    (29718, 29725, 'I-ORGANIZACAO'),
#    (29726, 29727, 'I-ORGANIZACAO'),
#    (29728, 29732, 'I-ORGANIZACAO'),
#    (30073, 30079, 'B-ORGANIZACAO'),
#    (30302, 30308, 'B-ORGANIZACAO'),
#    (30309, 30316, 'I-ORGANIZACAO'),
#    (30317, 30319, 'I-ORGANIZACAO'),
#    (30320, 30325, 'I-ORGANIZACAO'),
#    (30559, 30563, 'B-LEGISLACAO'),
#    (30564, 30565, 'I-LEGISLACAO'),
#    (30566, 30568, 'I-LEGISLACAO'),
#    (30569, 30570, 'I-LEGISLACAO'),
#    (30571, 30577, 'I-LEGISLACAO'),
#    (30578, 30579, 'I-LEGISLACAO'),
#    (30580, 30581, 'I-LEGISLACAO'),
#    (30582, 30583, 'I-LEGISLACAO'),
#    (30584, 30586, 'I-LEGISLACAO'),
#    (30587, 30588, 'I-LEGISLACAO'),
#    (30589, 30595, 'I-LEGISLACAO'),
#    (30596, 30597, 'I-LEGISLACAO'),
#    (30598, 30599, 'I-LEGISLACAO'),
#    (30600, 30602, 'I-LEGISLACAO'),
#    (30603, 30616, 'I-LEGISLACAO'),
#    (30617, 30625, 'I-LEGISLACAO'),
#    (30694, 30700, 'B-ORGANIZACAO'),
#    (30747, 30752, 'B-ORGANIZACAO'),
#    (30907, 30919, 'B-LEGISLACAO'),
#    (30920, 30926, 'I-LEGISLACAO'),
#    (31097, 31102, 'B-PESSOA'),
#    (31103, 31107, 'I-PESSOA'),
#    (31108, 31115, 'I-PESSOA'),
#    (31116, 31118, 'I-PESSOA'),
#    (31119, 31124, 'I-PESSOA'),
#    (31433, 31442, 'B-JURISPRUDENCIA'),
#    (31443, 31446, 'I-JURISPRUDENCIA'),
#    (31447, 31449, 'I-JURISPRUDENCIA'),
#    (31450, 31456, 'I-JURISPRUDENCIA'),
#    (31457, 31459, 'I-JURISPRUDENCIA'),
#    (31460, 31474, 'I-JURISPRUDENCIA'),
#    (31475, 31477, 'I-JURISPRUDENCIA'),
#    (31478, 31481, 'I-JURISPRUDENCIA'),
#    (31615, 31618, 'B-ORGANIZACAO'),
#    (31644, 31653, 'B-ORGANIZACAO'),
#    (32259, 32262, 'B-LEGISLACAO'),
#    (32263, 32264, 'I-LEGISLACAO'),
#    (32265, 32267, 'I-LEGISLACAO'),
#    (32268, 32269, 'I-LEGISLACAO'),
#    (32270, 32276, 'I-LEGISLACAO'),
#    (32277, 32279, 'I-LEGISLACAO'),
#    (32280, 32281, 'I-LEGISLACAO'),
#    (32282, 32283, 'I-LEGISLACAO'),
#    (32284, 32286, 'I-LEGISLACAO'),
#    (32287, 32288, 'I-LEGISLACAO'),
#    (32289, 32296, 'I-LEGISLACAO'),
#    (32297, 32298, 'I-LEGISLACAO'),
#    (32299, 32300, 'I-LEGISLACAO'),
#    (32301, 32302, 'I-LEGISLACAO'),
#    (32303, 32304, 'I-LEGISLACAO'),
#    (32305, 32306, 'I-LEGISLACAO'),
#    (32307, 32308, 'I-LEGISLACAO'),
#    (32309, 32310, 'I-LEGISLACAO'),
#    (32311, 32312, 'I-LEGISLACAO'),
#    (32313, 32315, 'I-LEGISLACAO'),
#    (32316, 32319, 'I-LEGISLACAO'),
#    (32320, 32322, 'I-LEGISLACAO'),
#    (32323, 32331, 'I-LEGISLACAO'),
#    (33501, 33506, 'B-PESSOA'),
#    (33507, 33511, 'I-PESSOA'),
#    (33512, 33519, 'I-PESSOA'),
#    (33520, 33522, 'I-PESSOA'),
#    (33523, 33528, 'I-PESSOA'),
#    (33611, 33614, 'B-LEGISLACAO'),
#    (33615, 33616, 'I-LEGISLACAO'),
#    (33617, 33619, 'I-LEGISLACAO'),
#    (33620, 33621, 'I-LEGISLACAO'),
#    (33622, 33628, 'I-LEGISLACAO'),
#    (33629, 33631, 'I-LEGISLACAO'),
#    (33632, 33633, 'I-LEGISLACAO'),
#    (33634, 33636, 'I-LEGISLACAO'),
#    (33637, 33640, 'I-LEGISLACAO'),
#    (33641, 33651, 'I-LEGISLACAO'),
#    (33759, 33762, 'B-ORGANIZACAO'),
#    (33791, 33798, 'B-PESSOA'),
#    (33799, 33806, 'I-PESSOA'),
#    (33807, 33812, 'I-PESSOA'),
#    (33813, 33815, 'I-PESSOA'),
#    (33816, 33821, 'I-PESSOA'),
#    (33827, 33829, 'B-TEMPO'),
#    (33830, 33832, 'I-TEMPO'),
#    (33833, 33841, 'I-TEMPO'),
#    (33842, 33844, 'I-TEMPO'),
#    (33845, 33849, 'I-TEMPO'),
#    (33861, 33866, 'B-PESSOA'),
#    (33867, 33873, 'I-PESSOA')]})

# %% [markdown]
# ## 03. Criando função para treinamento do modelo

# %% [markdown]
# ### Separando dados de treino e validação

# %%
import random

# %%
random.shuffle(documentos)

# %%
len(documentos)
# Out:
# 50

# %%
dados_treino = documentos[:40]
dados_validacao = documentos[40:]

# %%
len(dados_treino)
# Out:
# 40

# %% [markdown]
# ### Construindo a função de treinamento

# %% [markdown]
# [Modelos spacy](https://spacy.io/models/pt)

# %%
def treinar_modelo_ner(
    dados_treino: list[tuple[str, dict[str, tuple[int, int, str]]]],
    dados_validacao: list[tuple[str, dict[str, tuple[int, int, str]]]],
    epocas: int
):
    modelo = spacy.load('pt_core_news_sm')

    if 'ner' not in modelo.pipe_names:
        ner = modelo.create_pipe('ner')
        modelo.add_pipe(ner, last=True)
    else:
        ner = modelo.get_pipe('ner')

    for _, anotacoes in dados_treino:
       for ent in anotacoes.get('entities'):
           ner.add_label(ent[2])

    outros_pipelines = [pipeline for pipeline in modelo.pipe_names if pipeline != 'ner']

    with modelo.disable_pipes(*outros_pipelines):
        spacy.util.fix_random_seed()
        otimizador = modelo.create_optimizer()

# %% [markdown]
# ### Finalizando a função de treinamento

# %%
from tqdm import tqdm
from spacy.training import Example

# %%
def treinar_modelo_ner(
    dados_treino: list[tuple[str, dict[str, tuple[int, int, str]]]],
    dados_validacao: list[tuple[str, dict[str, tuple[int, int, str]]]],
    epocas: int
):
    modelo = spacy.load('pt_core_news_sm')

    if 'ner' not in modelo.pipe_names:
        ner = modelo.create_pipe('ner')
        modelo.add_pipe(ner, last=True)
    else:
        ner = modelo.get_pipe('ner')

    for _, anotacoes in dados_treino:
        for ent in anotacoes.get('entities'):
            ner.add_label(ent[2])

    outros_pipelines = [pipeline for pipeline in modelo.pipe_names if pipeline != 'ner']

    with modelo.disable_pipes(*outros_pipelines):
        spacy.util.fix_random_seed()
        otimizador = modelo.create_optimizer()

        for epoca in tqdm(range(epocas), desc='Treinando o modelo'):
            random.seed(10)
            random.shuffle(dados_treino)
            losses = {'ner': 0.0}

            for textos, anotacoes in dados_treino:
                exemplo = Example.from_dict(modelo.make_doc(textos), anotacoes)

                modelo.update([exemplo], drop=0.2, sgd=otimizador, losses=losses)

            print(f"\nÉpoca {epoca + 1} - Loss médio de treino: {losses['ner'] / len(dados_treino)}")

            val_losses = {'ner': 0.0}
            exemplos = []

            for textos, anotacoes in dados_validacao:
                exemplo = Example.from_dict(modelo.make_doc(textos), anotacoes)
                exemplos.append(exemplo)

            for exemplo in exemplos:
                modelo.update([exemplo], sgd=None, drop=0, losses=val_losses)

            print(f"Época {epoca + 1} - Loss médio de validação: {val_losses['ner'] / len(dados_validacao)}")

    return modelo

# %% [markdown]
# ### Para saber mais: uso de modelos pré-treinados em NLP
#
# No desenvolvimento de aplicações de processamento de linguagem natural (NLP), o uso de modelos pré-treinados pode economizar muito tempo e melhorar a eficiência. O **SpaCy** é uma biblioteca poderosa para NLP que oferece modelos pré-treinados para vários idiomas, permitindo tarefas como tokenização, lematização, reconhecimento de entidades nomeadas (NER) e análise de dependência sintática.
#
# #### Por que usar modelos pré-treinados?
#
# Modelos pré-treinados, como o "pt_core_news_sm" usado no SpaCy, já passaram por um treinamento com grandes conjuntos de dados de textos, como notícias e livros. Isso significa que o modelo já tem conhecimento linguístico básico e pode realizar tarefas de NLP sem precisar ser treinado do zero. Algumas vantagens incluem:
#
# 1. **Economia de tempo**: treinar um modelo do zero exige muitos dados e tempo de processamento, enquanto os modelos pré-treinados já tem uma base pronta para uso.
# 2. **Maior precisão**: os modelos pré-treinados são ajustados com grandes volumes de dados, resultando em uma compreensão melhor das nuances do idioma.
# 3. **Fácil customização**: embora os modelos pré-treinados possam ser usados como estão, é possível ajustá-los para tarefas específicas (como NER em documentos jurídicos), adicionando novas entidades ou ajustando os parâmetros.
#
# #### Personalizando um modelo com SpaCy
#
# Apesar dos modelos pré-treinados serem úteis, pode ser necessário adaptá-los para domínios específicos. Por exemplo, no caso do reconhecimento de entidades jurídicas, é possível adicionar entidades em documentos legais.
#
# O ajuste fino do modelo é realizado adicionando exemplos anotados ao conjunto de dados de treinamento e ajustando os parâmetros de atualização do modelo. Esse processo, chamado de **fine-tuning**, permite que o modelo aprenda novas informações sem perder os conhecimentos adquiridos anteriormente.

# %% [markdown]
# ## 04. Aplicando o modelo NER

# %% [markdown]
# ### Treinando e salvando o modelo

# %%
modelo_ner = treinar_modelo_ner(dados_treino, dados_validacao, 30)
# Out:
# Treinando o modelo:   0%|                                                                                                               | 0/30 [00:00<?, ?it/s]
# Época 1 - Loss médio de treino: 1032.9600578205511
# Treinando o modelo:   3%|███▍                                                                                                   | 1/30 [00:19<09:26, 19.53s/it]
# Época 1 - Loss médio de validação: 847.3997027244501
#
# Época 2 - Loss médio de treino: 691.3961379075932
# Treinando o modelo:   7%|██████▊                                                                                                | 2/30 [00:38<08:52, 19.02s/it]
# Época 2 - Loss médio de validação: 547.070226521073
#
# Época 3 - Loss médio de treino: 466.27601135854354
# Treinando o modelo:  10%|██████████▎                                                                                            | 3/30 [00:56<08:22, 18.61s/it]
# Época 3 - Loss médio de validação: 374.4989572449669
#
# Época 4 - Loss médio de treino: 350.44885287633855
# Treinando o modelo:  13%|█████████████▋                                                                                         | 4/30 [01:14<07:59, 18.45s/it]
# Época 4 - Loss médio de validação: 279.78036677684383
#
# Época 5 - Loss médio de treino: 278.326946402408
# Treinando o modelo:  17%|█████████████████▏                                                                                     | 5/30 [01:30<07:21, 17.68s/it]
# Época 5 - Loss médio de validação: 206.05745378244183
#
# Época 6 - Loss médio de treino: 241.37967142247072
# Treinando o modelo:  20%|████████████████████▌                                                                                  | 6/30 [01:47<06:57, 17.39s/it]
# Época 6 - Loss médio de validação: 214.2059732101293
#
# Época 7 - Loss médio de treino: 216.10697250563936
# Treinando o modelo:  23%|████████████████████████                                                                               | 7/30 [02:04<06:34, 17.13s/it]
# Época 7 - Loss médio de validação: 119.08291360433607
#
# Época 8 - Loss médio de treino: 184.4688862480285
# Treinando o modelo:  27%|███████████████████████████▍                                                                           | 8/30 [02:21<06:15, 17.05s/it]
# Época 8 - Loss médio de validação: 96.19955896042475
#
# Época 9 - Loss médio de treino: 164.39699301846252
# Treinando o modelo:  30%|██████████████████████████████▉                                                                        | 9/30 [02:39<06:03, 17.31s/it]
# Época 9 - Loss médio de validação: 64.54575531230246
#
# Época 10 - Loss médio de treino: 148.1734654295572
# Treinando o modelo:  33%|██████████████████████████████████                                                                    | 10/30 [02:56<05:49, 17.49s/it]
# Época 10 - Loss médio de validação: 49.331393405576165
#
# Época 11 - Loss médio de treino: 128.7897507841448
# Treinando o modelo:  37%|█████████████████████████████████████▍                                                                | 11/30 [03:14<05:32, 17.50s/it]
# Época 11 - Loss médio de validação: 43.46501353829292
#
# Época 12 - Loss médio de treino: 119.57970694722664
# Treinando o modelo:  40%|████████████████████████████████████████▊                                                             | 12/30 [03:31<05:12, 17.38s/it]
# Época 12 - Loss médio de validação: 40.036209231517766
#
# Época 13 - Loss médio de treino: 116.468213610864
# Treinando o modelo:  43%|████████████████████████████████████████████▏                                                         | 13/30 [03:48<04:51, 17.14s/it]
# Época 13 - Loss médio de validação: 35.763619911963126
#
# Época 14 - Loss médio de treino: 108.87343157655678
# Treinando o modelo:  47%|███████████████████████████████████████████████▌                                                      | 14/30 [04:04<04:32, 17.00s/it]
# Época 14 - Loss médio de validação: 29.09200864799821
#
# Época 15 - Loss médio de treino: 98.57768885678908
# Treinando o modelo:  50%|███████████████████████████████████████████████████                                                   | 15/30 [04:21<04:12, 16.81s/it]
# Época 15 - Loss médio de validação: 25.417925787206595
#
# Época 16 - Loss médio de treino: 91.31237966740598
# Treinando o modelo:  53%|██████████████████████████████████████████████████████▍                                               | 16/30 [04:38<03:55, 16.82s/it]
# Época 16 - Loss médio de validação: 28.74017786816383
#
# Época 17 - Loss médio de treino: 81.59111755810389
# Treinando o modelo:  57%|█████████████████████████████████████████████████████████▊                                            | 17/30 [04:55<03:40, 16.93s/it]
# Época 17 - Loss médio de validação: 23.929912515740032
#
# Época 18 - Loss médio de treino: 81.07325180926651
# Treinando o modelo:  60%|█████████████████████████████████████████████████████████████▏                                        | 18/30 [05:13<03:27, 17.26s/it]
# Época 18 - Loss médio de validação: 35.46162928808405
#
# Época 19 - Loss médio de treino: 81.59968635700025
# Treinando o modelo:  63%|████████████████████████████████████████████████████████████████▌                                     | 19/30 [05:31<03:12, 17.54s/it]
# Época 19 - Loss médio de validação: 21.03848828835386
#
# Época 20 - Loss médio de treino: 72.38389013939745
# Treinando o modelo:  67%|████████████████████████████████████████████████████████████████████                                  | 20/30 [05:49<02:57, 17.73s/it]
# Época 20 - Loss médio de validação: 22.520985633889868
#
# Época 21 - Loss médio de treino: 70.85032829715762
# Treinando o modelo:  70%|███████████████████████████████████████████████████████████████████████▍                              | 21/30 [06:07<02:40, 17.78s/it]
# Época 21 - Loss médio de validação: 19.496981499248022
#
# Época 22 - Loss médio de treino: 67.28137189824396
# Treinando o modelo:  73%|██████████████████████████████████████████████████████████████████████████▊                           | 22/30 [06:25<02:23, 17.89s/it]
# Época 22 - Loss médio de validação: 18.170270934755514
#
# Época 23 - Loss médio de treino: 60.89232637331825
# Treinando o modelo:  77%|██████████████████████████████████████████████████████████████████████████████▏                       | 23/30 [06:43<02:05, 18.00s/it]
# Época 23 - Loss médio de validação: 20.41816653242264
#
# Época 24 - Loss médio de treino: 64.11236046281086
# Treinando o modelo:  80%|█████████████████████████████████████████████████████████████████████████████████▌                    | 24/30 [07:02<01:49, 18.28s/it]
# Época 24 - Loss médio de validação: 18.095915101181657
#
# Época 25 - Loss médio de treino: 58.34124380460131
# Treinando o modelo:  83%|█████████████████████████████████████████████████████████████████████████████████████                 | 25/30 [07:21<01:31, 18.31s/it]
# Época 25 - Loss médio de validação: 21.505957279650026
#
# Época 26 - Loss médio de treino: 55.08513699646926
# Treinando o modelo:  87%|████████████████████████████████████████████████████████████████████████████████████████▍             | 26/30 [07:39<01:13, 18.42s/it]
# Época 26 - Loss médio de validação: 14.72487862256421
#
# Época 27 - Loss médio de treino: 54.76883228055401
# Treinando o modelo:  90%|███████████████████████████████████████████████████████████████████████████████████████████▊          | 27/30 [07:57<00:54, 18.29s/it]
# Época 27 - Loss médio de validação: 16.177918029371295
#
# Época 28 - Loss médio de treino: 52.08370468958553
# Treinando o modelo:  93%|███████████████████████████████████████████████████████████████████████████████████████████████▏      | 28/30 [08:15<00:35, 17.94s/it]
# Época 28 - Loss médio de validação: 12.254261998359654
#
# Época 29 - Loss médio de treino: 49.25513868482316
# Treinando o modelo:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████▌   | 29/30 [08:32<00:17, 17.81s/it]
# Época 29 - Loss médio de validação: 14.473525796027719
#
# Época 30 - Loss médio de treino: 43.00978043418301
# Treinando o modelo: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [08:49<00:00, 17.65s/it]
# Época 30 - Loss médio de validação: 15.80515208194674

# %%
# modelo_ner.to_disk('./modelo/')

# %%
# !zip -r ./modelo.zip modelo/
# Out:
#   adding: modelo/ (stored 0%)
#   adding: modelo/senter/ (stored 0%)
#   adding: modelo/senter/cfg (stored 0%)
#   adding: modelo/senter/model (deflated 10%)
#   adding: modelo/config.cfg (deflated 74%)
#   adding: modelo/ner/ (stored 0%)
#   adding: modelo/ner/cfg (deflated 33%)
#   adding: modelo/ner/moves (deflated 80%)
#   adding: modelo/ner/model (deflated 7%)
#   adding: modelo/vocab/ (stored 0%)
#   adding: modelo/vocab/key2row (stored 0%)
#   adding: modelo/vocab/vectors (deflated 45%)
#   adding: modelo/vocab/strings.json (deflated 78%)
#   adding: modelo/vocab/lookups.bin (stored 0%)
#   adding: modelo/vocab/vectors.cfg (stored 0%)
#   adding: modelo/attribute_ruler/ (stored 0%)
#   adding: modelo/attribute_ruler/patterns (deflated 76%)
#   adding: modelo/tokenizer (deflated 84%)
#   adding: modelo/parser/ (stored 0%)
#   adding: modelo/parser/cfg (deflated 32%)
#   adding: modelo/parser/moves (deflated 52%)
#   adding: modelo/parser/model (deflated 7%)
#   adding: modelo/tok2vec/ (stored 0%)
#   adding: modelo/tok2vec/cfg (stored 0%)
#   adding: modelo/tok2vec/model (deflated 7%)
#   adding: modelo/lemmatizer/ (stored 0%)
#   adding: modelo/lemmatizer/cfg (deflated 76%)
#   adding: modelo/lemmatizer/trees (deflated 80%)
#   adding: modelo/lemmatizer/model (deflated 7%)
#   adding: modelo/meta.json (deflated 87%)
#   adding: modelo/morphologizer/ (stored 0%)
#   adding: modelo/morphologizer/cfg (deflated 92%)
#   adding: modelo/morphologizer/model (deflated 7%)

# %% [markdown]
# ### Carregando e testando o modelo

# %%
# !unzip modelo.zip

# %%
modelo_ner = spacy.load('modelo')

# %%
doc = modelo_ner('João nasceu no dia 10/04/2010 em Florianópolis')

# %%
for entidade in doc.ents:
    print(f"{entidade.text} → {entidade.label_}")
# Out:
# João → B-PESSOA
# 10/04/2010 → B-TEMPO
# Florianópolis → B-LOCAL

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     João
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PESSOA</span>
# </mark>
#  nasceu no dia
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10/04/2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-TEMPO</span>
# </mark>
#  em
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florianópolis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOCAL</span>
# </mark>
# </div></span>

# %%
with open('20150110436469APC.txt', encoding='utf-8') as arquivo:
    texto = arquivo.read()

# texto = ftfy.fix_text(texto)

# %%
print(texto)
# Out:
# E M E N T A
# Poder Judiciário da União
# TRIBUNAL DE JUSTIÇA DO DISTRITO FEDERAL E TERRITÓRIOS Fls. _____
# Órgão : 8ª TURMA CÍVEL
# Classe : APELAÇÃO CÍVEL
# N. Processo : 20150110436469APC
# (0012843-03.2015.8.07.0001)
# Apelante(s) : BRASILIA CURSOS E CONCURSOS LTDA
# GRANCURSOS ESCOLA PARA
# CONCURSOS PUBLICOS LTDA
# Apelado(s) : ALISSON SILVA BATISTA DE MORAES
# Relatora : Desembargadora NÍDIA CORRÊA LIMA
# Acórdão N. : 1082726
# CIVIL E PROCESSUAL CIVIL. AÇÃO MONITÓRIA. CITAÇÃO
# REALIZADA APÓS O DECURSO DO PRAZO
# PRESCRICIONAL. PRESCRIÇÃO DA PRETENSÃO
# MONITÓRIA. RECONHECIMENTO. MANUTENÇÃO DA
# SENTENÇA.
# 1. Nos termos da Súmula nº 503 do colendo Superior Tribunal
# de Justiça, "O prazo para ajuizamento de ação monitória em
# face do emitente de cheque sem força executiva é quinquenal,
# a contar do dia seguinte à data de emissão estampada na
# cártula".
# 2. Evidenciado que a citação somente foi aperfeiçoada após o
# decurso do prazo prescricional, tem-se por correta a extinção
# da demanda monitória, com resolução do mérito, nos termos do
# artigo 485, inciso II, do Código de Processo Civil.
# 3. Recurso de Apelação conhecido e não provido.
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 1
# Fls. _____
# Apelação Cível 20150110436469APC
# A C Ó R D Ã O
# Acordam os Senhores Desembargadores da 8ª TURMA CÍVEL do
# Tribunal de Justiça do Distrito Federal e Territórios, NÍDIA CORRÊA LIMA -
# Relatora, DIAULAS COSTA RIBEIRO - 1º Vogal, EUSTÁQUIO DE CASTRO - 2º
# Vogal, sob a presidência do Senhor Desembargador DIAULAS COSTA RIBEIRO,
# em proferir a seguinte decisão: RECURSO DE APELAÇÃO CONHECIDO E NÃO
# PROVIDO. UNÂNIME., de acordo com a ata do julgamento e notas taquigráficas.
# Brasilia(DF), 15 de Março de 2018.
# Documento Assinado Eletronicamente
# NÍDIA CORRÊA LIMA
# Relatora
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 2
#
# Trata-se de ação monitória ajuizada por BRASILIA CURSOS E
# CONCURSOS LTDA GRANCURSOS ESCOLA PARA
# CONCURSOS PUBLICOS LTDA em desfavor de ALISSON
# SILVA BATISTA DE MORAES, partes qualificadas nos autos.
# Alega o autor que é credor do réu da importância representada
# por duas cártulas de cheques do Banco Real, no valor de R$
# 175,50 cada cártula, atualizado até 30/03/2015 em R$ 469,24.
# Requer a citação do réu para que pague a importância de R$
# 469,24 (quatrocentos e sessenta e nove reais e vinte e quatro
# centavos), acrescida de atualização e juros devidos, ou para
# que ofereça embargos, sob pena de ser convertido o mandado
# inicial em mandado executivo. Junta os documentos de fls.
# 04/10.
# Após diversas tentativas infrutíferas de citação pessoal, o réu
# foi citado por edital (fls. 80/81), mas deixou transcorrer "in albis"
# o prazo para defesa, conforme fl. 84. A Curadoria Especial
# ofertou embargos à ação monitória, por negativa geral (fl. 85).
# Manifestação do autor/embargado as fls. 89/90.
# Intimadas as partes a respeito de eventual prescrição,
# manifestaram-se as fls. 98/103 e 104-verso.
#
#  Acrescento que o d Magistrado sentenciante reconheceu a
# prescrição da pretensão monitória e, com fundamento no artigo 487, inciso II, do
# Código de Processo Civil, extinguiu o processo, com resolução do mérito,
# condenando a parte autora ao pagamento das custas judiciais e dos honorários
# advocatícios, estes fixados em 10% (dez por cento) do valor da causa.
# Fls. _____
# Apelação Cível 20150110436469APC
# R E L A T Ó R I O
#  Cuida-se de Apelação Cível interposta por BRASÍLIA CURSOS E
# CONCURSOS LTDA em face da r. sentença de fls. 105/107, cujo relatório
# transcrevo, in verbis:
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 3
#  Inconformado, o autor interpôs recurso de apelação às fls. 203/205,
# afirmando haver envidado todos os esforços para localizar o endereço do réu, sem,
# contudo, ter logrado êxito, razão pela qual promoveu a citação por edital.
#  Ao final, o autor alegou que não estaria configurada a prescrição da
# pretensão monitória, razão pela qual postulou a reforma da r. sentença, para que
# seja dado regular processamento do feito.
#  Preparo regular (fl. 116).
#  Contrarrazões ofertadas à fl. 117-v.
#  É o relatório.
# Fls. _____
# Apelação Cível 20150110436469APC
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 4
# Cuida-se de Apelação Cível interposta por BRASÍLIA CURSOS E
# CONCURSOS LTDA em face da r. sentença de fls. 105/107, pela qual o d.
# Magistrado de primeiro grau, com fundamento no artigo 487, inciso II, do Código de
# Processo Civil, julgou extinta a Ação Monitória proposta em desfavor de ALISSON
# SILVA BATISTA DE MORAES, ante o reconhecimento da prescrição da pretensão
# deduzida na inicial.
# Em suas razões de apelo, a autora afirmou que não poderia ter sido
# reconhecida aprescrição da pretensão monitória, uma vez que a não localização do
# apelado no prazo estipulado em lei não lhe pode ser imputada, porquanto adotou
# diversas medidas com a finalidade de promover a citação do réu.
# É a suma dos fatos.
# Da análise dos autos, tenho que o inconformismo manifestado pela
# autora não merece prosperar.
# Nos termos da Súmula nº 503 do colendo Superior Tribunal de
# Justiça, "O prazo para ajuizamento de ação monitória em face do emitente de
# cheque sem força executiva é quinquenal, a contar do dia seguinte à data de
# emissão estampada na cártula".
# Cabe ressaltar que, segundo o artigo 202, inciso I, do Código Civil, a
# interrupção da prescrição, que somente poderá ocorrer uma vez, dar-se-á "por
# despacho do juiz, mesmo incompetente, que ordenar a citação, se o interessado a
# promover no prazo e na forma da lei processual."
# Ressalte-se que, de acordo com o artigo 240, §§ 1º e 2º, do Código
# de Processo Civil, incumbe ao autor da ação, no prazo de 10 (dez) dias, viabilizar a
# citação do réu, sob pena de não ver interrompida a prescrição no momento do
# ajuizamento, mas apenas na data em que efetivamente for realizado o ato citatório.
# Neste sentido:
# No mesmo sentido cito a jurisprudência deste e. Tribunal de Justiça,
# in verbis:
# Fls. _____
# Apelação Cível 20150110436469APC
# V O T O S
# A Senhora Desembargadora NÍDIA CORRÊA LIMA - Relatora
# Conheço do recurso, porquanto presentes os pressupostos de
# admissibilidade.
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 5
# CIVIL E PROCESSUAL CIVIL. APELAÇÃO CÍVEL.
# EXECUÇÃO EXTRAJUDICIAL. CÉDULA DE CRÉDITO
# BANCÁRIO. PRESCRIÇÃO TRIENAL. CITAÇÃO POR EDITAL
# REALIZADA QUANDO PASSADOS MAIS DE OITO ANOS DO
# TERMO INICIAL DO PRAZO PRESCRICIONAL DA
# PRETENSÃO EXECUTÓRIA. CONSUMAÇÃO DA
# PRESCRIÇÃO. 1. A prescrição da pretensão executória
# fundada em cédula de crédito bancário é sujeita ao prazo
# trienal, consoante o disposto no art. 44, da Lei n.º 10.931/2004.
# 2. Em que pese o disposto no art. 202, inciso I, do CC, elencar
# como causa interruptiva da prescrição o despacho do juiz que
# determina a citação, esse preceito legal deve ser interpretado
# em conjunto com a exigência de que o autor promova o ato
# citatório no prazo e na forma da lei processual, isto é, em
# observância ao disposto no art. 240, § 2º, do CPC. 3. Nos
# termos do § 2º do art. 240 do CPC, incumbe à parte autora
# promover a citação do réu no prazo de dez (10) dias. Com
# efeito, embora referido prazo não seja peremptório, vale
# notar que a citação levada a efeito após o transcurso
# deste, não tem o condão de interromper a prescrição,
# retroagindo à data da propositura da ação (§ 1º do art. 240,
# do CPC), salvo se a demora na citação se der por motivos
# inerentes ao mecanismo da Justiça, consoante o § 3º do
# mesmo artigo do CPC e o Enunciado nº 106, do STJ, que
# não é o caso. 4. Feita a citação editalícia quando passados
# mais de oito (08) anos do início do curso do prazo prescricional,
# sem que se verifique, em data anterior, a ocorrência de
# qualquer outra causa interruptiva ou suspensiva do prazo
# prescricional, impõe-se o reconhecimento da prescrição. 5.
# Recurso não provido. Sentença mantida. (Acórdão n.999404,
# 20160610082800APC, Relator: ARNOLDO CAMANHO 4ª
# TURMA CÍVEL, Data de Julgamento: 22/02/2017, Publicado no
# DJE: 08/03/2017. Pág.: 283/300) - grifo nosso.
# Fls. _____
# Apelação Cível 20150110436469APC
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 6
# Compulsando os autos, verifica-se que as cártulas de cheques foram
# emitidas em 20/08/2010 e 20/09/2010 (fl. 9) e a Ação Monitória foi ajuizada em
# 20/04/2015.
# Cabe ressaltar que muito embora a demanda tenha sido ajuizada
# ainda dentro do prazo prescricional a parte autora não logrou promover a citação do
# réu dentro do prazo prescricional, sendo que a citação deste somente veio a ocorrer
# em 01/08/2016, na modalidade editalícia (fls. 80/81), quando já se encontrava
# exaurido o prazo prescricional.
# Percebe-se, assim, que entre o despacho inicial positivo, exarado
# em 22/04/2015, e a efetivação do ato citatório, ocorrido em 01/08/2016, decorreu,
# aproximadamente, um ano e seis meses, não se podendo falar, neste caso
# específico, em retroação da interrupção do lapso prescricional à data da propositura
# da demanda.
# Portanto, tenho por incensurável a r. sentença recorrida, ao
# reconhecer a prescrição da pretensão monitória.
# Pelas razões expostas, NEGO PROVIMENTO AO RECURSO DE
# APELAÇÃO e mantenho íntegra a r. sentença.
# É como voto.
# Fls. _____
# Apelação Cível 20150110436469APC
# O Senhor Desembargador DIAULAS COSTA RIBEIRO - Vogal
# Com o relator
# O Senhor Desembargador EUSTÁQUIO DE CASTRO - Vogal
# Com o relator
#  D E C I S Ã O
# Recurso de Apelação conhecido e não provido. Unânime.
# Código de Verificação :2018ACOIJG91GM498IVMWX8ID8A
# GABINETE DA DESEMBARGADORA NÍDIA CORRÊA LIMA 7

# %%
doc = modelo_ner(texto)

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">E
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#  E N T A<br>Poder Judiciário da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     União
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TRIBUNAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JUSTIÇA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOCAL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOCAL</span>
# </mark>
#  E TERRITÓRIOS Fls. _____<br>Órgão :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8ª
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TURMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CÍVEL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>Classe :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APELAÇÃO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
#  CÍVEL<br>N. Processo :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20150110436469APC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
# <br>(
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0012843-03.2015.8.07.0001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
# )<br>Apelante(s) :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRASILIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOCAL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOCAL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CONCURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LTDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GRANCURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#  ESCOLA PARA<br>CONCURSOS PUBLICOS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LTDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>Apelado(s) :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALISSON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SILVA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BATISTA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #ddd;

# %% [markdown]
# ### Para saber mais: exportação de modelo após o treinamento
#
# A exportação de um modelo de machine learning após o treinamento é uma etapa essencial para garantir que ele possa ser utilizado fora do ambiente de desenvolvimento. Esse processo não apenas facilita a aplicação prática do modelo, mas também assegura a integridade e a replicabilidade dos resultados obtidos durante o treinamento.
#
# #### Como funciona a exportação de modelos?
#
# 1. **Salvar o Modelo**: a função `to_disk()` é um método padrão em bibliotecas como SpaCy que permite salvar o modelo em um diretório específico. Isso não armazena apenas os pesos e as configurações do modelo, mas também sua arquitetura e metadados necessários para a reabilitação. Além disso, é recomendável incluir documentação sobre as versões de bibliotecas utilizadas e as configurações de treinamento.
# 2. **Carregando o Modelo**: o carregamento do modelo exportado em ambientes diferentes é feito utilizando bibliotecas específicas, como SpaCy. Com o comando `spacy.load()`, os desenvolvedores podem integrar o modelo rapidamente em suas aplicações, promovendo uma transição suave do ambiente de desenvolvimento para a produção. Além disso, ao carregar o modelo, é importante considerar a compatibilidade entre as versões das bibliotecas utilizadas durante o treinamento e o ambiente de produção.
# 3. **Testando a Integração**: após a exportação e o carregamento, realizar testes é fundamental parar garantir que o modelo funcione conforme esperado em novos dados. Testes devem incluir a avaliação do desempenho em um conjunto de dados de validação e a comparação com os resultados esperados. É recomendado também monitorar o desempenho do modelo em tempo real quando ele estiver em produção, para identificar possíveis desvios ou degradações na precisão com o passar do tempo.
#
# Para mais informações sobre a exportação e o uso de modelos NLP, confira o seguinte link:
#
# [Como salvar e carregar modelos no SpaCy](https://spacy.io/usage/saving-loading)

# %% [markdown]
# ### Alterando a visualização das cores

# %% [markdown]
# Cores:
# - Azul: #f0f8ff
# - Vermelho: #fa8072
# - Verde: #98fb98
# - Roxo: #dda0dd
# - Amarelo: #f0e68c
# - Rosa: #ffb6c1
# - Cinza: #d3d3d3

# %%
rotulos = list(modelo_ner.get_pipe('ner').labels)
rotulos
# Out:
# ['B-JURISPRUDENCIA',
#  'B-LEGISLACAO',
#  'B-LOCAL',
#  'B-ORGANIZACAO',
#  'B-PESSOA',
#  'B-TEMPO',
#  'I-JURISPRUDENCIA',
#  'I-LEGISLACAO',
#  'I-LOCAL',
#  'I-ORGANIZACAO',
#  'I-PESSOA',
#  'I-TEMPO',
#  'LOC',
#  'MISC',
#  'ORG',
#  'PER']

# %%
cores = {
    'B-JURISPRUDENCIA': '#f0f8ff',
    'B-LEGISLACAO': '#fa8072',
    'B-LOCAL': '#98fb98',
    'B-ORGANIZACAO': '#dda0dd',
    'B-PESSOA': '#f0e68c',
    'B-TEMPO': '#ffb6c1',
    'I-JURISPRUDENCIA': '#f0f8ff',
    'I-LEGISLACAO': '#fa8072',
    'I-LOCAL': '#98fb98',
    'I-ORGANIZACAO': '#dda0dd',
    'I-PESSOA': '#f0e68c',
    'I-TEMPO': '#ffb6c1',
    'LOC': '#d3d3d3',
    'MISC': '#d3d3d3',
    'ORG': '#d3d3d3',
    'PER': '#d3d3d3'
}

opcoes = {'ents': rotulos, 'colors': cores}
spacy.displacy.render(doc, style='ent', options=opcoes)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">E
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#  E N T A<br>Poder Judiciário da
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     União
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
# <br>
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TRIBUNAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JUSTIÇA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #98fb98; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOCAL</span>
# </mark>
#
# <mark class="entity" style="background: #98fb98; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOCAL</span>
# </mark>
#  E TERRITÓRIOS Fls. _____<br>Órgão :
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8ª
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TURMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CÍVEL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>Classe :
# <mark class="entity" style="background: #f0f8ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APELAÇÃO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
#  CÍVEL<br>N. Processo :
# <mark class="entity" style="background: #f0f8ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20150110436469APC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
# <br>(
# <mark class="entity" style="background: #f0f8ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0012843-03.2015.8.07.0001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
# )<br>Apelante(s) :
# <mark class="entity" style="background: #98fb98; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRASILIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOCAL</span>
# </mark>
#
# <mark class="entity" style="background: #98fb98; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOCAL</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CONCURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LTDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GRANCURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#  ESCOLA PARA<br>CONCURSOS PUBLICOS
# <mark class="entity" style="background: #dda0dd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LTDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>Apelado(s) :
# <mark class="entity" style="background: #f0e68c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALISSON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #f0e68c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SILVA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #f0e68c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BATISTA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #f0e68c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5r

# %% [markdown]
# ### Para saber mais: explorando os pipelines do SpaCy
#
# O SpaCy oferece uma variedade de pipelines que permitem realizar diversas tarefas linguísticas. Apesar do reconhecimento de entidades nomeadas (NER) ser uma das funcionalidades mais conhecidas, o SpaCy também oferece outros pipelines poderosos que podem ser utilizados em diferentes aplicações. Vamos explorar alguns deles e ver suas principais características.
#
# #### Tokenização
#
# A tokenização é o processo de dividir um texto em suas partes constituintes, chamadas de tokens. O SpaCy fornece um tokenizador altamente eficiente que considera as regras de divisão de palavras, como pontuação e espaços. A tokenização é uma etapa fundamental em muitas tarefas de NLP, pois permite a análise detalhada de textos.
#
# Exemplo de uso:
# ```
# nlp = spacy.load('pt_core_news_sm')
# doc = nlp(texto)
# for token in doc:
#     print(token.text)
# ```
#
# #### Lematização
#
# A lematização é o processo de reduzir uma palavra à sua forma base ou raiz. Por exemplo, as palavras "correr", "correndo", e "correu" podem ser reduzidas à forma base "correr". O SpaCy possui uma funcionalidade de lematização embutida que facilita a normalização de palavras, tornando-as mais uniformes para análise. Essa tarefa é útil para o processamento de texto para qualquer tipo de aplicação NLP.
#
# Exemplo de uso:
# ```
# nlp = spacy.load('pt_core_news_sm')
# doc = nlp(texto)
# for token in doc:
#     print(token.text, token.lemma_)
# ```
#
# #### Classificação de Texto
#
# A classificação de texto é uma tarefa que envolve atribuir uma ou mais categorias a um texto com base em seu conteúdo. O SpaCy oferece suporte para criar e treinar modelos de classificação de texto personalizados. Isso é especialmente útil para categorizar documentos, como notícias, e-mails ou comentários em redes sociais.
#
# Exemplo de uso:
# ```
# from spacy.pipeline.textcat import Config
#
# config = Config().from_str("""
# [model]
# @model = 'textcat'
# """)
# text_classifier = nlp.create_pipe('textcat', config=config)
# text_classifier.add_label('Positivo')
# text_classifier.add_label('Negativo')
# nlp.add_pipe(text_classifier)
# ```
#
# #### Análise Sintática (*Dependency Parsing*)
#
# A análise sintática, ou *dependency parsing*, é uma tarefa que envolve a identificação das relações gramaticais entre as palavras de uma frase. O modelo de análise sintática do SpaCy utiliza um gráfico de dependências para representar a estrutura da frase, permitindo entender como as palavras se conectam entre si. Isso é útil em aplicações como:
# - Extração de informações
# - Análise de sentimentos
# - Geração de linguagem natural
#
# Exemplo de uso:
# ```
# import spacy
#
# nlp = spacy.load('pt_core_news_sm')
# doc = nlp(texto)
# for token in doc:
#     print(token.text, token.dep_, token.head.text)
# ```

# %% [markdown]
# ## 05. Criando uma aplicação

# %% [markdown]
# ### Usando o Streamlit para reconhecer entidades

# %% [markdown]
# Vide `app.py`

# %% [markdown]
# ### Para saber mais: simplificando a criação de aplicações com Streamlit
#
# O **Streamlit** é uma biblioteca do Python que facilita a criação de aplicações web interativas para visualização de dados e machine learning. Seu principal atrativo é a simplicidade, permitindo a construção de interfaces gráficas usando apenas código Python, sem a necessidade de conhecimentos em front-end. Ele detecta automaticamente mudanças no código e atualiza a interface web em tempo real, o que facilita a experimentação e o desenvolvimento.
#
# #### Principais Métodos Disponíveis no Streamlit
#
# O Streamlit oferece uma variedade de métodos que facilitam a criação de aplicações interativas em Python. Abaixo estão listados alguns dos principais métodos disponíveis, com uma breve explicação e exemplos de suas funções.
#
# - **Título**: exibe um título na aplicação. Função: `st.title('Título')`
# - **Texto**: exibe um texto na interface. Função: `st.write('Texto exibido na aplicação')`
# - **Botão**: permite confirmar alguma execução do aplicativo. Função: `st.button('Nome do Botão')`
# - **Caixa de seleção**: exibe uam opção de marcer ou desmarcar, retornando o estado (marcado ou desmarcado). Função: `st.checkbox('Texto da Caixa de Seleção')`
# - **Slider**: permite selecionar um valor numérico dentro de um intervalo definido. Função: `st.slider('Texto do Slider', valor_minimo, valor_maximo)`
# - **Campo de texto**: possibilita a entrada de texto por parte do usuário. Função: `st.text_input('Texto de Entrada')`
# - **Seleção de opções**: cria uma lista suspensa para o usuário escolher uma opção. Função: `st.selectbox('Texto da Seleção', ['Opção 1', 'Opção 2', 'Opção 3'])`
# - **Multi-seleção**: permite que o usuário selecione múltiplas opções. Função: `st.multiselect('Texto da Multiseleção', ['Opção 1', 'Opção 2', 'Opção 3'])`
# - **Imagem**: exibe uma imagem na interface. Função: `st.image('caminho/para/imagem.jpg')`
# - **Gráfico de barras**: exibe um gráfico de barras a partir de um DataFrame ou array. Função: `st.bar_chart(dados)`
# - **Arquivo para upload**: possibilita que o usuário carregue arquivos para a aplicação. Função: `st.file_uploader('Texto de Upload', type=['csv', 'txt', 'pdf'])`
#
# #### Vantagens e Limitações
#
# Vantagens:
# - Facilide de uso: não requer habilidades em desevonvimento web.
# - Rápida prototipagem: ideal para criar protótipos de visualização e dashboards interativos.
# - Atualização em tempo real: a interface é atualizada automaticamente quando o código é modificado.
# - Integração com bibliotecas populares: funciona bem com bibliotecas de machine learning e visualização de dados.
#
# Limitações:
# - Customização limitada: em comparação com frameworks tradicionais, como Flask ou Django, o Streamlit tem menos opções de personalização visual.
# - Desempenho: aplicações muito complexas ou com muitos dados podem apresentar lentidão.
#
# Para aprender maais sobre as funcionalidades do Streamlit, confira a [documentação da biblioteca](https://streamlit.io/).

# %% [markdown]
# ## Para ir mais a fundo
#
# [SpaCy, documentação oficial](https://spacy.io/usage)
#
# [Artigo sobre reconhecimento de entidades nomeadas, Towards Data Science](https://towardsdatascience.com/how-to-create-a-custom-ner-in-spacy-3-5-c9942aab3c91)
